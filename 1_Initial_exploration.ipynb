# %% [markdown]
# # Exploratory Data Analysis of the Enron Dataset

# %% [markdown]
# ## Objectives of this notebook excercise:
# #### 1) Read the dataset provided in the link http://www2.aueb.gr/users/ion/data/enron-spam/
# #### 2) Perform a basic counts of spam and ham emails provided and visulaise how the data is provided
# #### 3) Perform simple NLP processes to build a tf-idf statisitics
# #### 4) Visualize the results of the NLP process
# #### 5) Explore some graphs that can be built with the data

# %%
# Importing the required libraries and using python 2.7
import glob
import os
import string
from collections import Counter

try:
    import pandas as pd
except:
    # !sudo pip install pandas
    import pandas as pd
import numpy as np
try:
    from nltk.corpus import stopwords
except:
    # !sudo pip install -U nltk
    from nltk.corpus import stopwords

try:
    import matplotlib
except:
    # !sudo pip install matplotlib
    import matplotlib

try:
    matplotlib.use("TkAgg")
except:
    matplotlib.use("agg")
import matplotlib.pyplot as plt

# Changing the directory level to the prject name
if("Code" in os.getcwd()):
    os.chdir("..")
print(os.getcwd())
# Out:
# /Users/gouravsanjuktabhabesh/pycharmProjects/freelance_work_1

# %% [markdown]
# #### Objective 1: Reading the dataset from the data downloaded from the provided link

# %%
# Reading the data set enron1 to enron6 from the Res folder
enron_folders = ["Res/enron"+str(x) for x in range(1,7)]
enron_spam_folders = [x + "/spam/" for x in enron_folders]
enron_ham_folders = [x + "/ham/" for x in enron_folders]

# Listing all the file names respectively with the type of mail
spam_mails = []
ham_mails = []
for i in range(len(enron_folders)):
    spam_mails.extend(glob.glob(enron_spam_folders[i] + "*.txt"))
    ham_mails.extend(glob.glob(enron_ham_folders[i] + "*.txt"))

# Stats for different types of mails in our data set
print("Number of spam mails in the Enron dataset provided = %s" % str(len(spam_mails)))
print("Number of ham mails in the Enron dataset provided = %s" % str(len(ham_mails)))
# Out:
# Number of spam mails in the Enron dataset provided = 17171
# Number of ham mails in the Enron dataset provided = 16545

# %% [markdown]
# #### Objective 2: Building a basic statistic of the labelled email data provided

# %%
# Function to extract various meta info from the row passed
# Adding following new meta columns:
# 1) id : some identity of the mail 
# 2) dataset : name of the enron datasets (enron 1 to enron 6)
# 3) date_mail : date on which mail was received
# 4) owner_mail : owner of the mail
# 5) content_message : contents of the mail
# 6) suject_message : subject of the mail
def extract_date_owner_content(row):
    val = row["file_name"].split(".")
    row["id"] = val[0].split("/")[-1]
    row["dataset"] = val[0].split("/")[1]
    row["date_mail"] = val[1]
    row["owner_mail"] = val[2]
    f = open(row["file_name"],"r")
    row["content_message"] = f.read()
    row["subject_message"] = str(row["content_message"]).split("\r\n")[0]
    return row

# %% [markdown]
# #### A) Spam Mails and its stats:

# %%
# Extracting the various meta info of the spam mails from the file name of the mail lists and construct a data frame
spam_metadata_df = pd.DataFrame(columns=["id","mail_label","file_name",
                                         "date_mail","owner_mail","content_message","subject_message"])
spam_metadata_df["file_name"] = spam_mails
spam_metadata_df["mail_label"] = "spam"
spam_metadata_df = spam_metadata_df.apply(lambda row: extract_date_owner_content(row), axis=1)
spam_metadata_df["date_mail"] = spam_metadata_df.apply(lambda x: pd.to_datetime(x["date_mail"], 
                                                                                format="%Y-%m-%d"),axis=1)
spam_metadata_df.head(5)
# Out:
#      id mail_label                                    file_name  date_mail  \
# 0  4743       spam  Res/enron1/spam/4743.2005-06-25.GP.spam.txt 2005-06-25
# 1  1309       spam  Res/enron1/spam/1309.2004-06-08.GP.spam.txt 2004-06-08
# 2  0726       spam  Res/enron1/spam/0726.2004-03-26.GP.spam.txt 2004-03-26
# 3  0202       spam  Res/enron1/spam/0202.2004-01-13.GP.spam.txt 2004-01-13
# 4  3988       spam  Res/enron1/spam/3988.2005-03-06.GP.spam.txt 2005-03-06
#
#   owner_mail                                    content_message  \
# 0         GP  Subject: what up , , your cam babe\r\nwhat are...
# 1         GP  Subject: want to make more money ?\r\norder co...
# 2         GP  Subject: food for thoughts\r\n[\r\njoin now - ...
# 3         GP  Subject: miningnews . net newsletter - tuesday...
# 4         GP  Subject: your pharmacy ta\r\nwould you want ch...
#
#                                      subject_message dataset
# 0                 Subject: what up , , your cam babe  enron1
# 1                 Subject: want to make more money ?  enron1
# 2                         Subject: food for thoughts  enron1
# 3  Subject: miningnews . net newsletter - tuesday...  enron1
# 4                          Subject: your pharmacy ta  enron1

# %% [markdown]
# #### Visualize the counts of spam mails being received by various owners

# %%
print(pd.DataFrame(spam_metadata_df.groupby("owner_mail").count()["id"].reset_index()).set_index("owner_mail"))
spam_mail_owner_date_count_df = pd.DataFrame(spam_metadata_df\
                        .groupby(["owner_mail","date_mail"]).count()["id"].reset_index()).set_index("date_mail")

# Plotiing the curve for the Spam mails date line
plt.close()
fig_size=[12,9]
plt.rcParams["figure.figsize"] = fig_size
plt.rcParams["figure.figsize"]

plt.subplot(3,1,1)
plt.title("Owner -> BG")
plt.ylabel("count")
spam_mail_owner_date_count_df.loc[spam_mail_owner_date_count_df["owner_mail"]=="BG"]["id"].reset_index().plot()

plt.subplot(3,1,2)
plt.title("Owner -> GP")
plt.ylabel("count")
spam_mail_owner_date_count_df.loc[spam_mail_owner_date_count_df["owner_mail"]=="GP"]["id"].reset_index().plot()

plt.subplot(3,1,3)
plt.title("Owner -> SA_and_HP")
plt.ylabel("count")
spam_mail_owner_date_count_df.loc[spam_mail_owner_date_count_df["owner_mail"]=="SA_and_HP"]["id"].reset_index().plot()
plt.subplots_adjust(hspace=2.0)

plt.savefig("Res/plot_spam_mails_date_curve.jpg")
print("Plot done!")
# Out:
#               id
# owner_mail
# BG          6000
# GP          6000
# SA_and_HP   5171

# %% [markdown]
# #### B) Ham Mails and its stats:

# %%
# Extracting the various meta info of the ham mails from the file name of the mail lists and construct a data frame
ham_metadata_df = pd.DataFrame(columns=["id","mail_label","file_name","date_mail","owner_mail",
                                        "content_message","subject_message"])
ham_metadata_df["file_name"] = ham_mails
ham_metadata_df["mail_label"] = "ham"
ham_metadata_df = ham_metadata_df.apply(lambda row: extract_date_owner_content(row), axis=1)
spam_metadata_df["date_mail"] = spam_metadata_df.apply(lambda x: pd.to_datetime(x["date_mail"],
                                                                                format="%Y-%m-%d"),axis=1)
ham_metadata_df.head(5)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-74cd01133960> in <module>()
#       5 ham_metadata_df["mail_label"] = "ham"
#       6 ham_metadata_df = ham_metadata_df.apply(lambda row: extract_date_owner_content(row), axis=1)
# ----> 7 spam_metadata_df["date_mail"] = spam_metadata_df.apply(lambda x: pd.to_datetime(x["date_mail"],
#       8                                                                                 format="%Y-%m-%d"),axis=1)
#       9 ham_metadata_df.head(5)
#
# NameError: name 'spam_metadata_df' is not defined

# %% [markdown]
# #### Visualize the counts of ham mails being received by various owners

# %%
print(pd.DataFrame(ham_metadata_df.groupby("owner_mail").count()["id"].reset_index()).set_index("owner_mail"))
ham_mail_owner_date_count_df = pd.DataFrame(ham_metadata_df\
                        .groupby(["owner_mail","date_mail"]).count()["id"].reset_index()).set_index("date_mail")

plt.close()
fig_size=[18,12]
plt.rcParams["figure.figsize"] = fig_size
plt.rcParams["figure.figsize"]
# Plotiing the curve for the Ham mails vs date line
plt.subplot(6,1,1)
plt.title("Owner -> farmer")
plt.ylabel("count")
ham_mail_owner_date_count_df.loc[ham_mail_owner_date_count_df["owner_mail"]=="farmer"]["id"].reset_index().plot()

plt.subplot(6,1,2)
plt.title("Owner -> beck")
plt.ylabel("count")
ham_mail_owner_date_count_df.loc[ham_mail_owner_date_count_df["owner_mail"]=="beck"]["id"].reset_index().plot()

plt.subplot(6,1,3)
plt.title("Owner -> kaminski")
plt.ylabel("count")
ham_mail_owner_date_count_df.loc[ham_mail_owner_date_count_df["owner_mail"]=="kaminski"]["id"].reset_index().plot()

plt.subplot(6,1,4)
plt.title("Owner -> kitchen")
plt.ylabel("count")
ham_mail_owner_date_count_df.loc[ham_mail_owner_date_count_df["owner_mail"]=="kitchen"]["id"].reset_index().plot()

plt.subplot(6,1,5)
plt.title("Owner -> lokay")
plt.ylabel("count")
ham_mail_owner_date_count_df.loc[ham_mail_owner_date_count_df["owner_mail"]=="lokay"]["id"].reset_index().plot()

plt.subplot(6,1,6)
plt.title("Owner -> williams")
plt.ylabel("count")
ham_mail_owner_date_count_df.loc[ham_mail_owner_date_count_df["owner_mail"]=="williams"]["id"].reset_index().plot()

plt.subplots_adjust(hspace=0.6)
plt.savefig("Res/plot_ham_mails_date_curve.jpg")
print("Plot done!")
# Out:
#               id
# owner_mail
# beck        1500
# farmer      3672
# kaminski    4361
# kitchen     4012
# lokay       1500
# williams    1500

# %% [markdown]
# ## Working on feature building from the messages of the enron dataset mails
# #### 1) Spam messages

# %%
# Counting the number of lines including the subject line
spam_metadata_df["line_count"] = spam_metadata_df.apply(lambda row: row["content_message"].count("\r\n"),axis=1)

# Extracting the tokens out of the messages in a column called "tokens"
# Removing the words "Subject:" from the mails as that is not the part of the mail
spam_metadata_df["tokens"] = spam_metadata_df.apply(lambda row: row["content_message"]\
    .replace("\\r\\n"," ").replace("."," . ").replace(","," , ").replace(";"," ; ")\
    .replace(":"," : ").replace("!"," ! ").replace("?"," ? ").replace("$"," $ ")\
    .replace("-"," - ").replace("="," = ").replace("&"," & ").replace("Subject :","")\
    .replace("/"," / ").split(),axis=1)

# Creating a column to count the total number of tokens
spam_metadata_df["token_count"] = spam_metadata_df.apply(lambda row: len(row["tokens"]),axis=1)

# Creating a column to count the number of punctuations
spam_metadata_df["punctuations_count"] = spam_metadata_df\
    .apply(lambda row: sum([True if x in string.punctuation else False for x in row["tokens"]]),axis=1)

# Single character count in the list of tokens
spam_metadata_df["single_char_count"] = spam_metadata_df\
    .apply(lambda row: sum([True if (len(x)==1 and x not in string.punctuation) else False for x in row["tokens"]]),axis=1)

# Column to count the tokens that are numbers 
spam_metadata_df["number_token_count"] = spam_metadata_df\
    .apply(lambda row: sum([True if x.isdigit() else False for x in row["tokens"]]),axis=1)

# Tokens that are years mentioned in between 1970 to 2050
spam_metadata_df["year_count"] = spam_metadata_df\
    .apply(lambda row: sum([True if (x >= "1970" and x <= "2050") else False for x in row["tokens"]]),axis=1)

# %%
spam_metadata_df[["line_count","tokens","token_count","punctuations_count","single_char_count",\
                  "number_token_count","year_count"]].head(5)
# Out:
#    line_count                                             tokens  token_count  \
# 0          14  [what, up, ,, ,, your, cam, babe, what, are, y...          184
# 1           9  [want, to, make, more, money, ?, order, confir...           72
# 2           6  [food, for, thoughts, [, join, now, -, take, a...           18
# 3          97  [miningnews, ., net, newsletter, -, tuesday, ,...         1026
# 4           2  [your, pharmacy, ta, would, you, want, cheap, ...           19
#
#    punctuations_count  single_char_count  number_token_count  year_count
# 0                  45                  4                   0           0
# 1                  15                  1                   0           0
# 2                   4                  1                   0           0
# 3                 161                 33                  58          17
# 4                   7                  0                   0           0

# %% [markdown]
# #### 2) Ham messages

# %%
# Counting the number of lines including the subject line
ham_metadata_df["line_count"] = ham_metadata_df.apply(lambda row: row["content_message"].count("\r\n"),axis=1)

# Extracting the tokens out of the messages in a column called "tokens"
ham_metadata_df["tokens"] = ham_metadata_df.apply(lambda row: row["content_message"]\
    .replace("\\r\\n"," ").replace("."," . ").replace(","," , ").replace(";"," ; ")\
    .replace(":"," : ").replace("!"," ! ").replace("?"," ? ").replace("$"," $ ")\
    .replace("-"," - ").replace("="," = ").replace("&"," & ").replace("/"," / ")\
    .replace("Subject :","").split(),axis=1)

# Creating a column to count the total number of tokens
ham_metadata_df["token_count"] = ham_metadata_df.apply(lambda row: len(row["tokens"]),axis=1)

# Creating a column to count the number of punctuations
ham_metadata_df["punctuations_count"] = ham_metadata_df\
    .apply(lambda row: sum([True if x in string.punctuation else False for x in row["tokens"]]),axis=1)

# Single character count in the list of tokens
ham_metadata_df["single_char_count"] = ham_metadata_df\
    .apply(lambda row: sum([True if (len(x)==1 and x not in string.punctuation) else False for x in row["tokens"]]),axis=1)

# Column to count the tokens that are numbers  
ham_metadata_df["number_token_count"] = ham_metadata_df\
    .apply(lambda row: sum([True if x.isdigit() else False for x in row["tokens"]]),axis=1)

# Tokens that are years mentioned in between 1970 to 2050
ham_metadata_df["year_count"] = ham_metadata_df\
    .apply(lambda row: sum([True if (x >= "1970" and x <= "2050") else False for x in row["tokens"]]),axis=1)

# %%
ham_metadata_df[["line_count","tokens","token_count","punctuations_count","single_char_count",\
                 "number_token_count","year_count"]].head(5)
# Out:
#    line_count                                             tokens  token_count  \
# 0          45  [ena, sales, on, hpl, just, to, update, you, o...          588
# 1          10  [98, -, 6736, &, 98, -, 9638, for, 1997, (, ua...          144
# 2           2  [hpl, nominations, for, december, 28, ,, 1999,...           22
# 3          14  [revised, nom, -, kcs, resources, daren, ,, it...          159
# 4          30  [new, production, -, sitara, deals, needed, da...          352
#
#    punctuations_count  single_char_count  number_token_count  year_count
# 0                 146                 41                  12           2
# 1                  37                 13                  38           1
# 2                   7                  0                   4           1
# 3                  80                  4                  17           2
# 4                 135                 18                  41           2

# %%
# Building a list of all spam and ham words
spam_word_list = []
for x in spam_metadata_df["tokens"]:
    spam_word_list.extend(x)

# Filtering the punctuations and numbers
spam_word_list = filter(lambda x: x.isdigit()==False and len(x)>3,spam_word_list)
    
ham_word_list = []
for x in ham_metadata_df["tokens"]:
    ham_word_list.extend(x)
# Filtering the punctuations and numbers
ham_word_list = filter(lambda x: x.isdigit()==False and len(x)>3,ham_word_list)

print("Spam word count = {}\nHam  word count = {}\nRatio of Spam to Ham word count = {}"\
      .format(len(spam_word_list),len(ham_word_list),len(spam_word_list)/float(len(ham_word_list))))
# Out:
# Spam word count = 2105555
# Ham  word count = 2567675
# Ratio of Spam to Ham word count = 0.820023951629

# %%
# Removing stop words and then finding the frequencies
stop_words = set(stopwords.words('english'))
spam_words_stop_filtered = []
for word in spam_word_list:
    if(word not in stop_words):
        spam_words_stop_filtered.append(word)
    
ham_words_stop_filtered = []
for word in ham_word_list:
    if(word not in stop_words):
        ham_words_stop_filtered.append(word)
        
print("Spam word count = {}\nHam  word count = {}\nRatio of Spam to Ham word count = {}"\
      .format(len(spam_words_stop_filtered),len(ham_words_stop_filtered),len(spam_words_stop_filtered)/float(len(ham_words_stop_filtered))))
# Out:
# Spam word count = 1819296
# Ham  word count = 2214541
# Ratio of Spam to Ham word count = 0.821522834754

# %%
# Threshold number of words to be accepted in the bag of words to be counted as significant
freq_tolerance_low = 100 # The number of word count that must occur for a word to be counted as significant
freq_tolerance_high = 4000 # The maximum number of word count to be considered significant
spam_words_freq = dict(Counter(spam_words_stop_filtered))
a1_sorted_keys = sorted(spam_words_freq, key=spam_words_freq.get, reverse=True)
spam_words_freq_dict_values = []
bag_of_words_spam = {}
for r in a1_sorted_keys:
    spam_words_freq_dict_values.append(spam_words_freq[r])
    if(spam_words_freq[r]>=freq_tolerance_low and spam_words_freq[r]<=freq_tolerance_high):
        bag_of_words_spam[r] = spam_words_freq[r]

# %%
# Threshold number of words to be accepted in the bag of words to be counted as significant
freq_tolerance_low = 100 # The number of word count that must occur for a word to be counted as significant
freq_tolerance_high = 4000 # The maximum number of word count to be considered significant
ham_words_freq = dict(Counter(ham_words_stop_filtered))
a1_sorted_keys = sorted(ham_words_freq, key=ham_words_freq.get, reverse=True)
ham_words_freq_dict_values = []
bag_of_words_ham = {}
for r in a1_sorted_keys:
    ham_words_freq_dict_values.append(ham_words_freq[r])
    if(ham_words_freq[r]>=freq_tolerance_low and ham_words_freq[r]<=freq_tolerance_high):
        bag_of_words_ham[r] = ham_words_freq[r]

# %%
spam_words_freq_dict_values1 = filter(lambda x: x>=freq_tolerance_low and x<=freq_tolerance_high,\
                                      spam_words_freq_dict_values)
plt.close()
fig_size=[9,6]
plt.rcParams["figure.figsize"] = fig_size
plt.rcParams["figure.figsize"]
plt.plot(range(0,len(spam_words_freq_dict_values1)),spam_words_freq_dict_values1)
plt.ylabel("Frequency count")
plt.xlabel("Word")
plt.title("Spam-Bag Of Words plot")
plt.savefig("Res/plot_spam_freq.jpg")

# %%
ham_words_freq_dict_values1 = filter(lambda x: x>=freq_tolerance_low and x<=freq_tolerance_high,\
                                      ham_words_freq_dict_values)
plt.close()
fig_size=[9,6]
plt.rcParams["figure.figsize"] = fig_size
plt.rcParams["figure.figsize"]
plt.plot(range(0,len(ham_words_freq_dict_values1)),ham_words_freq_dict_values1)
plt.ylabel("Frequency count")
plt.xlabel("Word")
plt.title("Ham-Bag Of Words plot")
plt.savefig("Res/plot_ham_freq.jpg")

# %%
# Defining a collection of words that are very RAREWORD
NOT_rareword = []
NOT_rareword.extend(bag_of_words_ham.keys())
NOT_rareword.extend(bag_of_words_spam.keys())

# Any word not in this list of NOT_garbage will be called as rareword
NOT_rareword = list(set(NOT_rareword))

with open('Res/NOT_rareword.txt', 'w') as f:
    for item in NOT_rareword:
        f.write("%s\n" % item)

# %%
# <-- SPAM messages -->

# Number of stopwords count in spam messages
spam_metadata_df["stopword_count"] = spam_metadata_df\
    .apply(lambda row: np.sum([True if x in stop_words else False for x in row["tokens"]]),axis=1)

# Number of useful words in the spam messages
spam_metadata_df["useful_tokens"] = spam_metadata_df\
    .apply(lambda row: filter(lambda x: x not in stop_words and 
                              x not in string.punctuation and 
                              x.isdigit()==False, row["tokens"]),axis=1)

# Median length of useful tokens in the spam messages
spam_metadata_df["median_useful_token_len"] = spam_metadata_df\
    .apply(lambda row: np.nanmedian([len(x) if len(x)!=1 else np.nan for x in row["useful_tokens"]]),axis=1)

# Average length of useful tokens in the spam messages
spam_metadata_df["avg_useful_token_len"] = spam_metadata_df\
    .apply(lambda row: np.nanmean([len(x) if len(x)!=1 else np.nan for x in row["useful_tokens"]]),axis=1)

# Extracting the rarewords in spam messages and storing them in a new column
spam_metadata_df["rareword_count"] = spam_metadata_df\
    .apply(lambda row: np.sum([True if x not in NOT_rareword else False for x in set(row["useful_tokens"])]),axis=1)
# Out:
# /Users/gouravsanjuktabhabesh/.conda/envs/ml_101_env/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:1019: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/gouravsanjuktabhabesh/.conda/envs/ml_101_env/lib/python2.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app

# %%
# <-- HAM messages -->

# Number of stopwords count in ham messages
ham_metadata_df["stopword_count"] = ham_metadata_df\
    .apply(lambda row: np.sum([True if x in stop_words else False for x in row["tokens"]]),axis=1)

# Number of useful words in the ham messages
ham_metadata_df["useful_tokens"] = ham_metadata_df\
    .apply(lambda row: filter(lambda x: x not in stop_words and 
                              x not in string.punctuation and 
                              x.isdigit()==False, row["tokens"]),axis=1)

# Median length of useful tokens in the message
ham_metadata_df["median_useful_token_len"] = spam_metadata_df\
    .apply(lambda row: np.nanmedian([len(x) if len(x)!=1 else np.nan for x in row["useful_tokens"]]),axis=1)

# Average length of useful tokens in the message
ham_metadata_df["avg_useful_token_len"] = ham_metadata_df\
    .apply(lambda row: np.nanmean([len(x) if len(x)!=1 else np.nan for x in row["useful_tokens"]]),axis=1)

# Extracting the rarewords in ham messages and storing them in a new column
ham_metadata_df["rareword_count"] = ham_metadata_df\
    .apply(lambda row: np.sum([True if x not in NOT_rareword else False for x in set(row["useful_tokens"])]),axis=1)

# %%
# Stemming and Lemmatization of the useful tokens
from nltk.stem import PorterStemmer
porter = PorterStemmer()

from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

def is_ascii(s):
    return all(ord(c) < 128 for c in s)

spam_metadata_df["stemmed_tokens"] = \
spam_metadata_df.apply(lambda row: [porter.stem(word) for word in filter(lambda x: len(x)>2 and is_ascii(x),row["useful_tokens"])],axis=1)

spam_metadata_df["lemma_tokens"] = \
spam_metadata_df.apply(lambda row: [wordnet_lemmatizer.lemmatize(word) for word in filter(lambda x: len(x)>2 and is_ascii(x),row["useful_tokens"])],axis=1)

ham_metadata_df["stemmed_tokens"] = \
ham_metadata_df.apply(lambda row: [porter.stem(word) for word in filter(lambda x: len(x)>2 and is_ascii(x),row["useful_tokens"])],axis=1)

ham_metadata_df["lemma_tokens"] = \
ham_metadata_df.apply(lambda row: [wordnet_lemmatizer.lemmatize(word) for word in filter(lambda x: len(x)>2 and is_ascii(x),row["useful_tokens"])],axis=1)

# %%
# The number of rarewords must be more for spam messages as they contain more vocabs and disparate words as compared to
# ham messages that contain simple and common words
print("Average for rarewords in spam messages = {}\nAverage for rarewords in ham  messages = {}"\
      .format(int(np.mean(spam_metadata_df[["rareword_count"]])),int(np.mean(ham_metadata_df[["rareword_count"]]))))
# which means more the count for rarewords would means it will be spam
# Out:
# Average for rarewords in spam messages = 40
# Average for rarewords in ham  messages = 28

# %%
final_spam_ham_df = pd.concat([spam_metadata_df,ham_metadata_df])
final_spam_ham_df.to_csv("Res/processed_data/final_spam_ham_df.csv",sep=",",index=False)
print("Length of the final spam plus ham dataset = {}".format(len(final_spam_ham_df)))
print("Completed !")
# Out:
# Length of the final spam plus ham dataset = 33716
# Completed !

# %%
final_spam_ham_df.groupby(["dataset","mail_label","owner_mail"]).count()["id"]
# Out:
# dataset  mail_label  owner_mail
# enron1   ham         farmer        3672
#          spam        GP            1500
# enron2   ham         kaminski      4361
#          spam        SA_and_HP     1496
# enron3   ham         kitchen       4012
#          spam        BG            1500
# enron4   ham         williams      1500
#          spam        GP            4500
# enron5   ham         beck          1500
#          spam        SA_and_HP     3675
# enron6   ham         lokay         1500
#          spam        BG            4500
# Name: id, dtype: int64

# %%
final_spam_ham_df.head()
# Out:
#          id mail_label                                     file_name  \
# 0      4743       spam   Res/enron1/spam/4743.2005-06-25.GP.spam.txt
# 1      1309       spam   Res/enron1/spam/1309.2004-06-08.GP.spam.txt
# 2      0726       spam   Res/enron1/spam/0726.2004-03-26.GP.spam.txt
# 3      0202       spam   Res/enron1/spam/0202.2004-01-13.GP.spam.txt
# 4      3988       spam   Res/enron1/spam/3988.2005-03-06.GP.spam.txt
# 5      0758       spam   Res/enron1/spam/0758.2004-04-02.GP.spam.txt
# 6      5145       spam   Res/enron1/spam/5145.2005-09-04.GP.spam.txt
# 7      4382       spam   Res/enron1/spam/4382.2005-04-26.GP.spam.txt
# 8      2794       spam   Res/enron1/spam/2794.2004-11-11.GP.spam.txt
# 9      1489       spam   Res/enron1/spam/1489.2004-07-03.GP.spam.txt
# 10     0391       spam   Res/enron1/spam/0391.2004-02-08.GP.spam.txt
# 11     3312       spam   Res/enron1/spam/3312.2004-12-27.GP.spam.txt
# 12     4735       spam   Res/enron1/spam/4735.2005-06-20.GP.spam.txt
# 13     2075       spam   Res/enron1/spam/2075.2004-09-04.GP.spam.txt
# 14     1993       spam   Res/enron1/spam/1993.2004-08-26.GP.spam.txt
# 15     1313       spam   Res/enron1/spam/1313.2004-06-09.GP.spam.txt
# 16     4577       spam   Res/enron1/spam/4577.2005-05-27.GP.spam.txt
# 17     3714       spam   Res/enron1/spam/3714.2005-02-05.GP.spam.txt
# 18     1180       spam   Res/enron1/spam/1180.2004-05-21.GP.spam.txt
# 19     0256       spam   Res/enron1/spam/0256.2004-01-20.GP.spam.txt
# 20     5132       spam   Res/enron1/spam/5132.2005-09-02.GP.spam.txt
# 21     3383       spam   Res/enron1/spam/3383.2005-01-04.GP.spam.txt
# 22     5020       spam   Res/enron1/spam/5020.2005-08-16.GP.spam.txt
# 23     1656       spam   Res/enron1/spam/1656.2004-07-19.GP.spam.txt
# 24     3042       spam   Res/enron1/spam/3042.2004-12-05.GP.spam.txt
# 25     0555       spam   Res/enron1/spam/0555.2004-02-22.GP.spam.txt
# 26     5155       spam   Res/enron1/spam/5155.2005-09-05.GP.spam.txt
# 27     1107       spam   Res/enron1/spam/1107.2004-05-15.GP.spam.txt
# 28     3591       spam   Res/enron1/spam/3591.2005-01-26.GP.spam.txt
# 29     2649       spam   Res/enron1/spam/2649.2004-10-27.GP.spam.txt
# ...     ...        ...                                           ...
# 16515  1784        ham  Res/enron6/ham/1784.2000-11-09.lokay.ham.txt
# 16516  4414        ham  Res/enron6/ham/4414.2001-08-31.lokay.ham.txt
# 16517  4576        ham  Res/enron6/ham/4576.2001-09-25.lokay.ham.txt
# 16518  5696        ham  Res/enron6/ham/5696.2002-02-22.lokay.ham.txt
# 16519  4777        ham  Res/enron6/ham/4777.2001-10-18.lokay.ham.txt
# 16520  1317        ham  Res/enron6/ham/1317.2000-10-06.lokay.ham.txt
# 16521  2640        ham  Res/enron6/ham/2640.2001-01-19.lokay.ham.txt
# 16522  4618        ham  Res/enron6/ham/4618.2001-09-29.lokay.ham.txt
# 16523  4762        ham  Res/enron6/ham/4762.2001-10-17.lokay.ham.txt
# 16524  2402        ham  Res/enron6/ham/2402.2001-01-05.lokay.ham.txt
# 16525  2507        ham  Res/enron6/ham/2507.2001-01-12.lokay.ham.txt
# 16526  4533        ham  Res/enron6/ham/4533.2001-09-20.lokay.ham.txt
# 16527  4048        ham  Res/enron6/ham/4048.2001-07-24.lokay.ham.txt
# 16528  4967        ham  Res/enron6/ham/4967.2001-11-12.lokay.ham.txt
# 16529  1266        ham  Res/enron6/ham/1266.2000-10-05.lokay.ham.txt
# 16530  2129        ham  Res/enron6/ham/2129.2000-12-04.lokay.ham.txt
# 16531  1095        ham  Res/enron6/ham/1095.2000-09-17.lokay.ham.txt
# 16532  1776        ham  Res/enron6/ham/1776.2000-11-08.lokay.ham.txt
# 16533  5290        ham  Res/enron6/ham/5290.2002-01-10.lokay.ham.txt
# 16534  5649        ham  Res/enron6/ham/5649.2002-02-19.lokay.ham.txt
# 16535  5747        ham  Res/enron6/ham/5747.2002-02-28.lokay.ham.txt
# 16536  4691        ham  Res/enron6/ham/4691.2001-10-05.lokay.ham.txt
# 16537  4229        ham  Res/enron6/ham/4229.2001-08-14.lokay.ham.txt
# 16538  3864        ham  Res/enron6/ham/3864.2001-06-27.lokay.ham.txt
# 16539  4022        ham  Res/enron6/ham/4022.2001-07-20.lokay.ham.txt
# 16540  0935        ham  Res/enron6/ham/0935.2000-09-01.lokay.ham.txt
# 16541  4247        ham  Res/enron6/ham/4247.2001-08-14.lokay.ham.txt
# 16542  0359        ham  Res/enron6/ham/0359.2000-07-13.lokay.ham.txt
# 16543  2743        ham  Res/enron6/ham/2743.2001-01-26.lokay.ham.txt
# 16544  0663        ham  Res/enron6/ham/0663.2000-08-08.lokay.ham.txt
#
#                  date_mail owner_mail  \
# 0      2005-06-25 00:00:00         GP
# 1      2004-06-08 00:00:00         GP
# 2      2004-03-26 00:00:00         GP
# 3      2004-01-13 00:00:00         GP
# 4      2005-03-06 00:00:00         GP
# 5      2004-04-02 00:00:00         GP
# 6      2005-09-04 00:00:00         GP
# 7      2005-04-26 00:00:00         GP
# 8      2004-11-11 00:00:00         GP
# 9      2004-07-03 00:00:00         GP
# 10     2004-02-08 00:00:00         GP
# 11     2004-12-27 00:00:00         GP
# 12     2005-06-20 00:00:00         GP
# 13     2004-09-04 00:00:00         GP
# 14     2004-08-26 00:00:00         GP
# 15     2004-06-09 00:00:00         GP
# 16     2005-05-27 00:00:00         GP
# 17     2005-02-05 00:00:00         GP
# 18     2004-05-21 00:00:00         GP
# 19     2004-01-20 00:00:00         GP
# 20     2005-09-02 00:00:00         GP
# 21     2005-01-04 00:00:00         GP
# 22     2005-08-16 00:00:00         GP
# 23     2004-07-19 00:00:00         GP
# 24     2004-12-05 00:00:00         GP
# 25     2004-02-22 00:00:00         GP
# 26     2005-09-05 00:00:00         GP
# 27     2004-05-15 00:00:00         GP
# 28     2005-01-26 00:00:00         GP
# 29     2004-10-27 00:00:00         GP
# ...                    ...        ...
# 16515           2000-11-09      lokay
# 16516           2001-08-31      lokay
# 16517           2001-09-25      lokay
# 16518           2002-02-22      lokay
# 16519           2001-10-18      lokay
# 16520           2000-10-06      lokay
# 16521           2001-01-19      lokay
# 16522           2001-09-29      lokay
# 16523           2001-10-17      lokay
# 16524           2001-01-05      lokay
# 16525           2001-01-12      lokay
# 16526           2001-09-20      lokay
# 16527           2001-07-24      lokay
# 16528           2001-11-12      lokay
# 16529           2000-10-05      lokay
# 16530           2000-12-04      lokay
# 16531           2000-09-17      lokay
# 16532           2000-11-08      lokay
# 16533           2002-01-10      lokay
# 16534           2002-02-19      lokay
# 16535           2002-02-28      lokay
# 16536           2001-10-05      lokay
# 16537           2001-08-14      lokay
# 16538           2001-06-27      lokay
# 16539           2001-07-20      lokay
# 16540           2000-09-01      lokay
# 16541           2001-08-14      lokay
# 16542           2000-07-13      lokay
# 16543           2001-01-26      lokay
# 16544           2000-08-08      lokay
#
#                                          content_message  \
# 0      Subject: what up , , your cam babe\r\nwhat are...
# 1      Subject: want to make more money ?\r\norder co...
# 2      Subject: food for thoughts\r\n[\r\njoin now - ...
# 3      Subject: miningnews . net newsletter - tuesday...
# 4      Subject: your pharmacy ta\r\nwould you want ch...
# 5      Subject: bigger breast just from a pill\r\nima...
# 6      Subject: cant find you on msn . . .\r\nbut rid...
# 7      Subject: majestic rx\r\n- - - - 86738490004042...
# 8      Subject: quick way to buy soft - ware\r\nvarie...
# 9      Subject: so , it ' s me , varenukha\r\nsorry f...
# 10     Subject: cfp : int . conf . on web delivering ...
# 11     Subject: some advice to him\r\nmon , 27 dec 20...
# 12     Subject: software at incredibly low prices ( 8...
# 13                                         Subject: \r\n
# 14     Subject: - want a new laptop ? - get one free ...
# 15     Subject: victory at last\r\nwed , 09 jun 2004 ...
# 16     Subject: fw : win - dows xp + office xp = 80 d...
# 17     Subject: the bast phharma out ther - same da -...
# 18     Subject: patent\r\nthad madrid , !\r\nthe c @ ...
# 19     Subject: = ? iso - 8859 - 7 ? q ? = 5 b = 3 f ...
# 20     Subject: replica rolex and other popular brand...
# 21     Subject: enjoy your partner\r\nhttp : / / diet...
# 22     Subject: funny\r\nmay aplomb be angola may pri...
# 23     Subject: allergies bothering you ? buy drugs o...
# 24     Subject: pain is killing you\r\nsun , 05 dec 2...
# 25     Subject: feeling down about the slze of your j...
# 26     Subject: he ' s gone for the night\r\nyou ' ve...
# 27     Subject: buy your medicines from us , viagra ,...
# 28     Subject: save a bundle on meds !\r\nfont color...
# 29     Subject: security alert on microsoft internet ...
# ...                                                  ...
# 16515  Subject: re : outstanding invoices\r\ndave sai...
# 16516  Subject: september lst contract status ( as of...
# 16517  Subject: eol confirmation - transwestern pipel...
# 16518  Subject: ferc 101 / 102 : march 4 - 5 chicago ...
# 16519  Subject: comments on socal gir proposed decisi...
# 16520  Subject: williams announces sketchy open seaso...
# 16521  Subject: nng capacity books training\r\nplease...
# 16522  Subject: transwestern capacity release report ...
# 16523  Subject: etc - theatre event - the diary of an...
# 16524  Subject: tw weekly 1 / 5 / 01\r\nattached is t...
# 16525  Subject: january 12 th update\r\njeff / michel...
# 16526  Subject: enron principal investments - organiz...
# 16527  Subject: clickathome order verification\r\nthe...
# 16528  Subject: gas 200\r\nstructuring natural gas tr...
# 16529  Subject: development center course offerings\r...
# 16530  Subject: wallpaper\r\njust open this file in y...
# 16531  Subject: hea 34 th annual sports tournament re...
# 16532  Subject: organizational announcement\r\ni am p...
# 16533  Subject: fw : you are invited to an open seaso...
# 16534  Subject: fw : article\r\n- - - - - original me...
# 16535  Subject: re : available capacity\r\nperry - bp...
# 16536  Subject: topock lateral expansion - 300 mmcf /...
# 16537  Subject: tw capacity\r\nmichelle ,\r\nas per o...
# 16538  Subject: docs\r\nlittle mell ,\r\nlook at thes...
# 16539  Subject: etc - theatre event - last call - smo...
# 16540  Subject: bullets 9 / 1\r\nel paso pipeline upd...
# 16541  Subject: eog material\r\ni understand that eog...
# 16542  Subject: associate / analyst fall recruiting\r...
# 16543  Subject: tw bullets 1 / 26\r\ncapacity marketi...
# 16544  Subject: dashboard enhancements\r\nin our cont...
#
#                                          subject_message dataset  line_count  \
# 0                     Subject: what up , , your cam babe  enron1          14
# 1                     Subject: want to make more money ?  enron1           9
# 2                             Subject: food for thoughts  enron1           6
# 3      Subject: miningnews . net newsletter - tuesday...  enron1          97
# 4                              Subject: your pharmacy ta  enron1           2
# 5                Subject: bigger breast just from a pill  enron1           3
# 6                    Subject: cant find you on msn . . .  enron1          15
# 7                                   Subject: majestic rx  enron1           8
# 8                  Subject: quick way to buy soft - ware  enron1          37
# 9                    Subject: so , it ' s me , varenukha  enron1          46
# 10     Subject: cfp : int . conf . on web delivering ...  enron1         124
# 11                           Subject: some advice to him  enron1          10
# 12     Subject: software at incredibly low prices ( 8...  enron1           8
# 13                                             Subject:   enron1           1
# 14       Subject: - want a new laptop ? - get one free !  enron1           1
# 15                              Subject: victory at last  enron1          15
# 16     Subject: fw : win - dows xp + office xp = 80 d...  enron1           1
# 17     Subject: the bast phharma out ther - same da -...  enron1           9
# 18                                       Subject: patent  enron1           8
# 19     Subject: = ? iso - 8859 - 7 ? q ? = 5 b = 3 f ...  enron1          17
# 20       Subject: replica rolex and other popular brands  enron1          24
# 21                           Subject: enjoy your partner  enron1           8
# 22                                        Subject: funny  enron1           6
# 23     Subject: allergies bothering you ? buy drugs o...  enron1           6
# 24                          Subject: pain is killing you  enron1           2
# 25     Subject: feeling down about the slze of your j...  enron1          10
# 26                    Subject: he ' s gone for the night  enron1          10
# 27     Subject: buy your medicines from us , viagra ,...  enron1           6
# 28                      Subject: save a bundle on meds !  enron1          38
# 29     Subject: security alert on microsoft internet ...  enron1          20
# ...                                                  ...     ...         ...
# 16515                 Subject: re : outstanding invoices  enron6           3
# 16516  Subject: september lst contract status ( as of...  enron6           5
# 16517  Subject: eol confirmation - transwestern pipel...  enron6          26
# 16518  Subject: ferc 101 / 102 : march 4 - 5 chicago ...  enron6          42
# 16519   Subject: comments on socal gir proposed decision  enron6           1
# 16520  Subject: williams announces sketchy open seaso...  enron6          31
# 16521               Subject: nng capacity books training  enron6          30
# 16522  Subject: transwestern capacity release report ...  enron6           4
# 16523  Subject: etc - theatre event - the diary of an...  enron6          18
# 16524                      Subject: tw weekly 1 / 5 / 01  enron6           2
# 16525                      Subject: january 12 th update  enron6           5
# 16526  Subject: enron principal investments - organiz...  enron6           4
# 16527            Subject: clickathome order verification  enron6          10
# 16528                                   Subject: gas 200  enron6          32
# 16529       Subject: development center course offerings  enron6           8
# 16530                                 Subject: wallpaper  enron6           3
# 16531  Subject: hea 34 th annual sports tournament re...  enron6          16
# 16532               Subject: organizational announcement  enron6          14
# 16533  Subject: fw : you are invited to an open seaso...  enron6          43
# 16534                              Subject: fw : article  enron6          16
# 16535                   Subject: re : available capacity  enron6          26
# 16536   Subject: topock lateral expansion - 300 mmcf / d  enron6           1
# 16537                               Subject: tw capacity  enron6          10
# 16538                                      Subject: docs  enron6           6
# 16539  Subject: etc - theatre event - last call - smo...  enron6          16
# 16540                             Subject: bullets 9 / 1  enron6          36
# 16541                              Subject: eog material  enron6          21
# 16542       Subject: associate / analyst fall recruiting  enron6           6
# 16543                         Subject: tw bullets 1 / 26  enron6           6
# 16544                    Subject: dashboard enhancements  enron6          27
#
#                                                   tokens  \
# 0      [what, up, ,, ,, your, cam, babe, what, are, y...
# 1      [want, to, make, more, money, ?, order, confir...
# 2      [food, for, thoughts, [, join, now, -, take, a...
# 3      [miningnews, ., net, newsletter, -, tuesday, ,...
# 4      [your, pharmacy, ta, would, you, want, cheap, ...
# 5      [bigger, breast, just, from, a, pill, image, i...
# 6      [cant, find, you, on, msn, ., ., ., but, ride,...
# 7      [majestic, rx, -, -, -, -, 8673849000404220545...
# 8      [quick, way, to, buy, soft, -, ware, variety, ...
# 9      [so, ,, it, ', s, me, ,, varenukha, sorry, for...
# 10     [cfp, :, int, ., conf, ., on, web, delivering,...
# 11     [some, advice, to, him, mon, ,, 27, dec, 2004,...
# 12     [software, at, incredibly, low, prices, (, 83,...
# 13                                                    []
# 14     [-, want, a, new, laptop, ?, -, get, one, free...
# 15     [victory, at, last, wed, ,, 09, jun, 2004, 13,...
# 16     [fw, :, win, -, dows, xp, +, office, xp, =, 80...
# 17     [the, bast, phharma, out, ther, -, same, da, -...
# 18     [patent, thad, madrid, ,, !, the, c, @, ble, -...
# 19     [=, ?, iso, -, 8859, -, 7, ?, q, ?, =, 5, b, =...
# 20     [replica, rolex, and, other, popular, brands, ...
# 21     [enjoy, your, partner, http, :, /, /, dietred,...
# 22     [funny, may, aplomb, be, angola, may, prize, s...
# 23     [allergies, bothering, you, ?, buy, drugs, onl...
# 24     [pain, is, killing, you, sun, ,, 05, dec, 2004...
# 25     [feeling, down, about, the, slze, of, your, jo...
# 26     [he, ', s, gone, for, the, night, you, ', ve, ...
# 27     [buy, your, medicines, from, us, ,, viagra, ,,...
# 28     [save, a, bundle, on, meds, !, font, color, =,...
# 29     [security, alert, on, microsoft, internet, exp...
# ...                                                  ...
# 16515  [re, :, outstanding, invoices, dave, said, tha...
# 16516  [september, lst, contract, status, (, as, of, ...
# 16517  [eol, confirmation, -, transwestern, pipeline,...
# 16518  [ferc, 101, /, 102, :, march, 4, -, 5, chicago...
# 16519  [comments, on, socal, gir, proposed, decision,...
# 16520  [williams, announces, sketchy, open, season, r...
# 16521  [nng, capacity, books, training, please, plan,...
# 16522  [transwestern, capacity, release, report, -, 9...
# 16523  [etc, -, theatre, event, -, the, diary, of, an...
# 16524  [tw, weekly, 1, /, 5, /, 01, attached, is, tw,...
# 16525  [january, 12, th, update, jeff, /, michelle, ,...
# 16526  [enron, principal, investments, -, organizatio...
# 16527  [clickathome, order, verification, the, clicka...
# 16528  [gas, 200, structuring, natural, gas, transact...
# 16529  [development, center, course, offerings, seats...
# 16530  [wallpaper, just, open, this, file, in, your, ...
# 16531  [hea, 34, th, annual, sports, tournament, remi...
# 16532  [organizational, announcement, i, am, pleased,...
# 16533  [fw, :, you, are, invited, to, an, open, seaso...
# 16534  [fw, :, article, -, -, -, -, -, original, mess...
# 16535  [re, :, available, capacity, perry, -, bp, wan...
# 16536  [topock, lateral, expansion, -, 300, mmcf, /, ...
# 16537  [tw, capacity, michelle, ,, as, per, our, conv...
# 16538  [docs, little, mell, ,, look, at, these, ;, le...
# 16539  [etc, -, theatre, event, -, last, call, -, smo...
# 16540  [bullets, 9, /, 1, el, paso, pipeline, update,...
# 16541  [eog, material, i, understand, that, eog, tran...
# 16542  [associate, /, analyst, fall, recruiting, corr...
# 16543  [tw, bullets, 1, /, 26, capacity, marketing, -...
# 16544  [dashboard, enhancements, in, our, continuing,...
#
#                              ...                          single_char_count  \
# 0                            ...                                          4
# 1                            ...                                          1
# 2                            ...                                          1
# 3                            ...                                         33
# 4                            ...                                          0
# 5                            ...                                         13
# 6                            ...                                          3
# 7                            ...                                          6
# 8                            ...                                         16
# 9                            ...                                         12
# 10                           ...                                         25
# 11                           ...                                         12
# 12                           ...                                          0
# 13                           ...                                          0
# 14                           ...                                          1
# 15                           ...                                          2
# 16                           ...                                          3
# 17                           ...                                          3
# 18                           ...                                          1
# 19                           ...                                         45
# 20                           ...                                         13
# 21                           ...                                          3
# 22                           ...                                          1
# 23                           ...                                          2
# 24                           ...                                          0
# 25                           ...                                          0
# 26                           ...                                          2
# 27                           ...                                          4
# 28                           ...                                         49
# 29                           ...                                          1
# ...                          ...                                        ...
# 16515                        ...                                          0
# 16516                        ...                                        102
# 16517                        ...                                         13
# 16518                        ...                                         34
# 16519                        ...                                          2
# 16520                        ...                                          9
# 16521                        ...                                         10
# 16522                        ...                                         10
# 16523                        ...                                         14
# 16524                        ...                                          3
# 16525                        ...                                          1
# 16526                        ...                                          5
# 16527                        ...                                          5
# 16528                        ...                                          3
# 16529                        ...                                         16
# 16530                        ...                                          0
# 16531                        ...                                          3
# 16532                        ...                                          4
# 16533                        ...                                         29
# 16534                        ...                                         22
# 16535                        ...                                          6
# 16536                        ...                                          3
# 16537                        ...                                          3
# 16538                        ...                                          2
# 16539                        ...                                         20
# 16540                        ...                                         26
# 16541                        ...                                         10
# 16542                        ...                                          2
# 16543                        ...                                         15
# 16544                        ...                                          5
#
#        number_token_count  year_count  stopword_count  \
# 0                       0           0            59.0
# 1                       0           0            20.0
# 2                       0           0             6.0
# 3                      58          17           239.0
# 4                       0           0             2.0
# 5                       0           0            39.0
# 6                       0           0            28.0
# 7                       3           0            30.0
# 8                      33           7            23.0
# 9                       2           1            45.0
# 10                     56          18           313.0
# 11                     10           1            28.0
# 12                      1           0            13.0
# 13                      0           0             0.0
# 14                      0           0             1.0
# 15                      8           1            32.0
# 16                      2           0            43.0
# 17                      0           0            22.0
# 18                      1           0            10.0
# 19                     15           1            54.0
# 20                     16           3            20.0
# 21                      5           1             5.0
# 22                      0           0            14.0
# 23                      0           0            11.0
# 24                      6           1             2.0
# 25                      0           0             5.0
# 26                      0           0            30.0
# 27                      0           0            32.0
# 28                     29           4            70.0
# 29                      1           1            59.0
# ...                   ...         ...             ...
# 16515                   0           0            11.0
# 16516                 236           4            60.0
# 16517                  32           4            30.0
# 16518                  29           5           293.0
# 16519                   0           0            19.0
# 16520                  11           2           118.0
# 16521                  16           2            37.0
# 16522                   8           2            68.0
# 16523                  21           1            77.0
# 16524                   6           0             8.0
# 16525                   2           0             7.0
# 16526                   1           1            64.0
# 16527                  11           2            37.0
# 16528                   4           1            99.0
# 16529                  22           1            20.0
# 16530                   0           0            11.0
# 16531                   9           0            52.0
# 16532                   1           1            60.0
# 16533                  45          12           127.0
# 16534                  23           8           144.0
# 16535                  29           9            44.0
# 16536                   2           0            10.0
# 16537                   7           0             7.0
# 16538                   0           0            10.0
# 16539                  26           2            55.0
# 16540                  37           4           167.0
# 16541                   6           0           107.0
# 16542                   4           0            19.0
# 16543                  21           4           127.0
# 16544                   9           1            78.0
#
#                                            useful_tokens  \
# 0      [cam, babe, looking, looking, companion, frien...
# 1      [want, make, money, order, confirmation, order...
# 2      [food, thoughts, join, take, free, tour, click...
# 3      [miningnews, net, newsletter, tuesday, january...
# 4      [pharmacy, ta, would, want, cheap, perscriptio...
# 5      [bigger, breast, pill, image, loading, cli, k,...
# 6      [cant, find, msn, ride, january, exercise, beb...
# 7      [majestic, rx, hi, varou, quickly, work, take,...
# 8      [quick, way, buy, soft, ware, variety, top, ma...
# 9      [varenukha, sorry, taking, long, finally, foun...
# 10     [cfp, int, conf, web, delivering, music, wedel...
# 11     [advice, mon, dec, good, day, viewing, record,...
# 12     [software, incredibly, low, prices, lower, unc...
# 13                                                    []
# 14                   [want, new, laptop, get, one, free]
# 15     [victory, last, wed, jun, sir, madam, thank, m...
# 16     [fw, win, dows, xp, office, xp, dol, lars, get...
# 17     [bast, phharma, ther, da, shijpping, chromium,...
# 18     [patent, thad, madrid, c, ble, filter, allow, ...
# 19     [iso, q, b, f, want, pills, fviagr, cval, ef, ...
# 20     [replica, rolex, popular, brands, hi, get, rep...
# 21     [enjoy, partner, http, dietred, biz, toyz, sto...
# 22     [funny, may, aplomb, angola, may, prize, workl...
# 23     [allergies, bothering, buy, drugs, online, mit...
# 24                             [pain, killing, sun, dec]
# 25     [feeling, slze, johnson, rtxyj, nxfgr, ktrqr, ...
# 26     [gone, night, got, check, new, site, somebody,...
# 27     [buy, medicines, us, viagra, xanax, doctor, vi...
# 28     [save, bundle, meds, font, color, whiteisaac, ...
# 29     [security, alert, microsoft, internet, explore...
# ...                                                  ...
# 16515  [outstanding, invoices, dave, said, thanks, fi...
# 16516  [september, lst, contract, status, august, st,...
# 16517  [eol, confirmation, transwestern, pipeline, co...
# 16518  [ferc, march, chicago, ill, understanding, fer...
# 16519  [comments, socal, gir, proposed, decision, att...
# 16520  [williams, announces, sketchy, open, season, r...
# 16521  [nng, capacity, books, training, please, plan,...
# 16522  [transwestern, capacity, release, report, atta...
# 16523  [etc, theatre, event, diary, anne, frank, main...
# 16524  [tw, weekly, attached, tw, weekly, questions, ...
# 16525  [january, th, update, jeff, michelle, go, upda...
# 16526  [enron, principal, investments, organizational...
# 16527  [clickathome, order, verification, clickathome...
# 16528  [gas, structuring, natural, gas, transactions,...
# 16529  [development, center, course, offerings, seats...
# 16530  [wallpaper, open, file, internet, browser, rig...
# 16531  [hea, th, annual, sports, tournament, reminder...
# 16532  [organizational, announcement, pleased, announ...
# 16533  [fw, invited, open, season, reception, desert,...
# 16534  [fw, article, original, message, taylor, gina,...
# 16535  [available, capacity, perry, bp, wants, know, ...
# 16536  [topock, lateral, expansion, mmcf, attached, l...
# 16537  [tw, capacity, michelle, per, conversation, mi...
# 16538  [docs, little, mell, look, let, know, think, y...
# 16539  [etc, theatre, event, last, call, smokey, joe,...
# 16540  [bullets, el, paso, pipeline, update, us, dept...
# 16541  [eog, material, understand, eog, transferred, ...
# 16542  [associate, analyst, fall, recruiting, correct...
# 16543  [tw, bullets, capacity, marketing, sempra, ren...
# 16544  [dashboard, enhancements, continuing, effort, ...
#
#        median_useful_token_len avg_useful_token_len  rareword_count  \
# 0                          5.0             5.712500            46.0
# 1                          6.0             6.081081             8.0
# 2                          4.0             5.000000             0.0
# 3                          6.0             6.264654           165.0
# 4                          4.5             5.200000             5.0
# 5                          5.0             5.517241             9.0
# 6                          6.0             6.222222            47.0
# 7                          6.0             6.183673            16.0
# 8                          6.0             6.642105            16.0
# 9                          7.0             6.800699           267.0
# 10                         7.0             7.015175           126.0
# 11                         5.0             5.192308            17.0
# 12                         5.0             5.293103            22.0
# 13                         NaN                  NaN             0.0
# 14                         3.5             3.833333             3.0
# 15                         6.0             6.080645            39.0
# 16                         4.0             4.952381            16.0
# 17                         7.0             6.726027            63.0
# 18                         5.5             5.533333            15.0
# 19                         6.0             6.000000            37.0
# 20                         4.0             4.750000            25.0
# 21                         5.0             5.681818            13.0
# 22                         6.0             5.807692            24.0
# 23                         7.0             7.278261           318.0
# 24                         3.5             4.250000             3.0
# 25                         5.0             5.137931            56.0
# 26                         4.5             5.224138            41.0
# 27                         5.0             4.964286            10.0
# 28                         5.0             5.757085            88.0
# 29                         8.0             7.336957            16.0
# ...                        ...                  ...             ...
# 16515                      6.0             5.888889             1.0
# 16516                      9.0             5.473118            59.0
# 16517                      6.0             6.130435            29.0
# 16518                      6.0             6.482692            93.0
# 16519                      5.0             6.222222             5.0
# 16520                      4.0             6.407960            29.0
# 16521                      6.5             5.538462            34.0
# 16522                      5.0             6.529412            16.0
# 16523                      8.0             5.807692            49.0
# 16524                      6.0             5.375000             2.0
# 16525                      7.0             5.357143             4.0
# 16526                      4.0             6.883333            27.0
# 16527                      6.5             6.511111             7.0
# 16528                      7.5             6.969697            47.0
# 16529                      6.0             7.175000             9.0
# 16530                      5.0             5.307692             4.0
# 16531                      5.0             5.905405            13.0
# 16532                      6.0             7.270588            19.0
# 16533                      5.0             6.417625            51.0
# 16534                      7.0             6.693227            48.0
# 16535                      6.0             6.047619            25.0
# 16536                      4.0             6.937500             3.0
# 16537                      5.5             5.696970             9.0
# 16538                      5.0             4.423077            12.0
# 16539                      6.5             5.381356            42.0
# 16540                      6.0             6.455645            43.0
# 16541                      6.0             5.990291            30.0
# 16542                      4.5             6.121951             3.0
# 16543                      5.0             6.386667            48.0
# 16544                      6.0             6.300000            23.0
#
#                                           stemmed_tokens  \
# 0      [cam, babe, look, look, companion, friendship,...
# 1      [want, make, money, order, confirm, order, shi...
# 2      [food, thought, join, take, free, tour, click,...
# 3      [miningnew, net, newslett, tuesday, januari, t...
# 4      [pharmaci, would, want, cheap, perscript, http...
# 5      [bigger, breast, pill, imag, load, cli, info, ...
# 6      [cant, find, msn, ride, januari, exercis, bebu...
# 7      [majest, varou, quickli, work, take, minut, lo...
# 8      [quick, way, buy, soft, ware, varieti, top, ma...
# 9      [varenukha, sorri, take, long, final, found, s...
# 10     [cfp, int, conf, web, deliv, music, wedelmus, ...
# 11     [advic, mon, dec, good, day, view, record, una...
# 12     [softwar, incred, low, price, lower, unconscio...
# 13                                                    []
# 14                   [want, new, laptop, get, one, free]
# 15     [victori, last, wed, jun, sir, madam, thank, m...
# 16     [win, dow, offic, dol, lar, get, oem, softwar,...
# 17     [bast, phharma, ther, shijp, chromium, sure, o...
# 18     [patent, thad, madrid, ble, filter, allow, rec...
# 19     [iso, want, pill, fviagr, cval, iso, frdllad, ...
# 20     [replica, rolex, popular, brand, get, replica,...
# 21     [enjoy, partner, http, dietr, biz, toyz, stop,...
# 22     [funni, may, aplomb, angola, may, prize, workl...
# 23     [allergi, bother, buy, drug, onlin, mitt, ambu...
# 24                                [pain, kill, sun, dec]
# 25     [feel, slze, johnson, rtxyj, nxfgr, ktrqr, abt...
# 26     [gone, night, got, check, new, site, somebodi,...
# 27     [buy, medicin, viagra, xanax, doctor, visit, n...
# 28     [save, bundl, med, font, color, whiteisaac, ce...
# 29     [secur, alert, microsoft, internet, explor, de...
# ...                                                  ...
# 16515  [outstand, invoic, dave, said, thank, find, al...
# 16516  [septemb, lst, contract, statu, august, final,...
# 16517  [eol, confirm, transwestern, pipelin, compani,...
# 16518  [ferc, march, chicago, ill, understand, ferc, ...
# 16519  [comment, socal, gir, propos, decis, attach, r...
# 16520  [william, announc, sketchi, open, season, resu...
# 16521  [nng, capac, book, train, pleas, plan, attend,...
# 16522  [transwestern, capac, releas, report, attach, ...
# 16523  [etc, theatr, event, diari, ann, frank, main, ...
# 16524    [weekli, attach, weekli, question, pleas, call]
# 16525  [januari, updat, jeff, michel, updat, attach, ...
# 16526  [enron, princip, invest, organiz, memo, enron,...
# 16527  [clickathom, order, verif, clickathom, databas...
# 16528  [ga, structur, natur, ga, transact, cours, bui...
# 16529  [develop, center, cours, offer, seat, still, a...
# 16530  [wallpap, open, file, internet, browser, right...
# 16531  [hea, annual, sport, tournament, remind, miche...
# 16532  [organiz, announc, pleas, announc, effect, nov...
# 16533  [invit, open, season, recept, desert, cross, g...
# 16534  [articl, origin, messag, taylor, gina, sent, f...
# 16535  [avail, capac, perri, want, know, capac, exist...
# 16536  [topock, later, expans, mmcf, attach, level, c...
# 16537  [capac, michel, per, convers, mirant, america,...
# 16538  [doc, littl, mell, look, let, know, think, you...
# 16539  [etc, theatr, event, last, call, smokey, joe, ...
# 16540  [bullet, paso, pipelin, updat, dept, transport...
# 16541  [eog, materi, understand, eog, transfer, fund,...
# 16542  [associ, analyst, fall, recruit, correct, supe...
# 16543  [bullet, capac, market, sempra, renegoti, firm...
# 16544  [dashboard, enhanc, continu, effort, expand, d...
#
#                                             lemma_tokens
# 0      [cam, babe, looking, looking, companion, frien...
# 1      [want, make, money, order, confirmation, order...
# 2      [food, thought, join, take, free, tour, click,...
# 3      [miningnews, net, newsletter, tuesday, january...
# 4      [pharmacy, would, want, cheap, perscriptions, ...
# 5      [bigger, breast, pill, image, loading, cli, in...
# 6      [cant, find, msn, ride, january, exercise, beb...
# 7      [majestic, varou, quickly, work, take, minute,...
# 8      [quick, way, buy, soft, ware, variety, top, ma...
# 9      [varenukha, sorry, taking, long, finally, foun...
# 10     [cfp, int, conf, web, delivering, music, wedel...
# 11     [advice, mon, dec, good, day, viewing, record,...
# 12     [software, incredibly, low, price, lower, unco...
# 13                                                    []
# 14                   [want, new, laptop, get, one, free]
# 15     [victory, last, wed, jun, sir, madam, thank, m...
# 16     [win, dows, office, dol, lars, get, oem, softw...
# 17     [bast, phharma, ther, shijpping, chromium, sur...
# 18     [patent, thad, madrid, ble, filter, allow, rec...
# 19     [iso, want, pill, fviagr, cval, iso, frdllad, ...
# 20     [replica, rolex, popular, brand, get, replica,...
# 21     [enjoy, partner, http, dietred, biz, toyz, sto...
# 22     [funny, may, aplomb, angola, may, prize, workl...
# 23     [allergy, bothering, buy, drug, online, mitt, ...
# 24                             [pain, killing, sun, dec]
# 25     [feeling, slze, johnson, rtxyj, nxfgr, ktrqr, ...
# 26     [gone, night, got, check, new, site, somebody,...
# 27     [buy, medicine, viagra, xanax, doctor, visit, ...
# 28     [save, bundle, med, font, color, whiteisaac, c...
# 29     [security, alert, microsoft, internet, explore...
# ...                                                  ...
# 16515  [outstanding, invoice, dave, said, thanks, fin...
# 16516  [september, lst, contract, status, august, fin...
# 16517  [eol, confirmation, transwestern, pipeline, co...
# 16518  [ferc, march, chicago, ill, understanding, fer...
# 16519  [comment, socal, gir, proposed, decision, atta...
# 16520  [williams, announces, sketchy, open, season, r...
# 16521  [nng, capacity, book, training, please, plan, ...
# 16522  [transwestern, capacity, release, report, atta...
# 16523  [etc, theatre, event, diary, anne, frank, main...
# 16524  [weekly, attached, weekly, question, please, c...
# 16525  [january, update, jeff, michelle, update, atta...
# 16526  [enron, principal, investment, organizational,...
# 16527  [clickathome, order, verification, clickathome...
# 16528  [gas, structuring, natural, gas, transaction, ...
# 16529  [development, center, course, offering, seat, ...
# 16530  [wallpaper, open, file, internet, browser, rig...
# 16531  [hea, annual, sport, tournament, reminder, mic...
# 16532  [organizational, announcement, pleased, announ...
# 16533  [invited, open, season, reception, desert, cro...
# 16534  [article, original, message, taylor, gina, sen...
# 16535  [available, capacity, perry, want, know, capac...
# 16536  [topock, lateral, expansion, mmcf, attached, l...
# 16537  [capacity, michelle, per, conversation, mirant...
# 16538  [doc, little, mell, look, let, know, think, yo...
# 16539  [etc, theatre, event, last, call, smokey, joe,...
# 16540  [bullet, paso, pipeline, update, dept, transpo...
# 16541  [eog, material, understand, eog, transferred, ...
# 16542  [associate, analyst, fall, recruiting, correct...
# 16543  [bullet, capacity, marketing, sempra, renegoti...
# 16544  [dashboard, enhancement, continuing, effort, e...
#
# [33716 rows x 22 columns]

# %%
print("Completed!")
# Out:
# Completed!
