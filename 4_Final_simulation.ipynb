# %% [markdown]
# ### Final simulation for testing the best model on a batch of increasing 100 samples in the train set and test on the next 100 batch

# %%
# Importing the required libraries
import numpy as np
import os
import pandas as pd
from ast import literal_eval

from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB

# Libraries for xgboost,light gradient boosting and Cat boosting
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

# We can build some calibaration curve
from sklearn.calibration import calibration_curve

import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt

import random
# Chaning back to the resource directory if it is not there
if("Res" not in os.getcwd()):
    os.chdir("..")
# Out:
# /Users/gouravsanjuktabhabesh/.conda/envs/ml_101_env/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Reading the input file for this notebook called attributes_df.csv containing the attributes of each mail
# extracted earlier
attributes_hot_encode = pd.read_csv("Res/processed_data/attributes_df.csv",sep=",")

# Removing those mails that have no text inside them such as Res/enron1/spam/1733.2004-07-29.GP.spam.txt
attributes_hot_encode.drop(attributes_hot_encode.index\
                           [np.where(np.isnan(attributes_hot_encode[["median_useful_token_len"]]))[0]],inplace=True)
col_attributes = []
with open("Res/processed_data/attributes_names.txt", 'r') as f:
    col_attributes.extend(f.read().split())

# %%
# Change this value from "enron1" to "enron6" to build all the simulations
enron_dataset_list = ["enron1","enron2","enron3","enron4","enron5","enron6"]
for enron_dataset in enron_dataset_list:
    print("Running simulation for "+enron_dataset+"...")
    attributes_hot_encode_ordered = attributes_hot_encode.loc[attributes_hot_encode["dataset"]==enron_dataset].sort_values("date_mail")
    attributes_hot_encode_1_spam = attributes_hot_encode_ordered.loc[(attributes_hot_encode_ordered["dataset"]==enron_dataset) &
                                                             (attributes_hot_encode_ordered["mail_label"]=="spam")]
    attributes_hot_encode_1_ham = attributes_hot_encode_ordered.loc[(attributes_hot_encode_ordered["dataset"]==enron_dataset) &
                                                             (attributes_hot_encode_ordered["mail_label"]=="ham")]

    attributes_hot_encoded_df = pd.DataFrame(columns = list(attributes_hot_encode_ordered))
    i = 0
    if(len(attributes_hot_encode_1_ham)>len(attributes_hot_encode_1_spam)):
        for j in range(len(attributes_hot_encode_1_spam)):
            ham_count = np.random.choice([0,1,2,3,4,5,6,7],p=[0.025,0.15,0.25,0.25,0.15,0.10,0.05,0.025])
            try:
                attributes_hot_encoded_df = pd.concat([attributes_hot_encoded_df,
                                                       attributes_hot_encode_1_spam.iloc[j:j+1],
                                                       attributes_hot_encode_1_ham.iloc[i:i+ham_count]])
                i+=ham_count
                if(j==len(attributes_hot_encode_1_spam)-1):
                    attributes_hot_encoded_df = pd.concat([attributes_hot_encoded_df,
                                                           attributes_hot_encode_1_ham.iloc[i:]])
            except:
                attributes_hot_encoded_df = pd.concat([attributes_hot_encoded_df,
                                                       attributes_hot_encode_1_spam.iloc[j:]])
                break
    else:
        for j in range(len(attributes_hot_encode_1_ham)):
            spam_count = np.random.choice([0,1,2,3,4,5,6,7],p=[0.025,0.15,0.25,0.25,0.15,0.10,0.05,0.025])
            try:
                attributes_hot_encoded_df = pd.concat([attributes_hot_encoded_df,
                                                       attributes_hot_encode_1_ham.iloc[j:j+1],
                                                       attributes_hot_encode_1_spam.iloc[i:i+spam_count]])
                i+=spam_count
                if(j==len(attributes_hot_encode_1_ham)-1):
                    attributes_hot_encoded_df = pd.concat([attributes_hot_encoded_df,
                                                           attributes_hot_encode_1_spam.iloc[i:]])
            except:
                attributes_hot_encoded_df = pd.concat([attributes_hot_encoded_df,
                                                       attributes_hot_encode_1_ham.iloc[j:]])
                break
    f = list(attributes_hot_encoded_df["mail_label"])
    train_df = pd.DataFrame(columns=list(attributes_hot_encoded_df))
    measure_after_iteration = pd.DataFrame(columns = ["Train_spam_count","Train_ham_count","Test_spam_count",
                                                      "Test_ham_count","True_negative","False_positive",
                                                      "False_negative","True_positive","ratio_per_batch"])
    for i in range((len(f)/100)-1):
        train_df = pd.concat([train_df,attributes_hot_encoded_df.iloc[i*100:((i+1)*100)]])
        if(i==(len(f)/100)-2):
            test_df = attributes_hot_encoded_df.iloc[(i+1)*100:]
        else:
            test_df = attributes_hot_encoded_df.iloc[(i+1)*100:((i+2)*100)]
        print("train = {}, test = {}".format(len(train_df),len(test_df)))

        baseline_X_features = ['line_count', 'token_count', 'punctuations_count', 'single_char_count', 
                             'number_token_count', 'year_count', 'stopword_count','median_useful_token_len', 
                             'avg_useful_token_len', 'rareword_count','attributes_len']
        for col in baseline_X_features:
            train_df[col] = train_df[col].astype(float)
            test_df[col] = test_df[col].astype(float)
        baseline_X_features.extend(col_attributes)
        Y_feature = "mail_label"

        X_train = train_df[baseline_X_features]
        y_train = train_df[Y_feature]

        X_test = test_df[baseline_X_features]
        y_test = test_df[Y_feature]

        y_train["label"] = y_train.apply(lambda x: 1.0 if x=="spam" else 0.0)
        y_test["label"] = y_test.apply(lambda x: 1.0 if x=="spam" else 0.0)

        dtrain = xgb.DMatrix(X_train, label=y_train["label"])
        dtest = xgb.DMatrix(X_test, label=y_test["label"])

        param = {'max_depth': 100, 'eta': 1, 'verbosity': 0, 'objective': 'binary:logistic',"n_estimators": [200]}
        param['nthread'] = 4
        param['eval_metric'] =  ['auc']

        evallist = [(dtest, 'eval'), (dtrain, 'train')]

        num_round = 30
        try:
            bst = xgb.train(param, dtrain, num_round, evallist)
        except:
            break
        y_pred = bst.predict(dtest)
        y_pred = pd.Series(y_pred).apply(lambda x: 1.0 if x>0.5 else 0.0)

        tn, fp, fn, tp = confusion_matrix(y_test["label"], y_pred).ravel()
        print("True Positives(spam) = {}".format(tp))
        print("True Negatives(ham)  = {}".format(tn))
        print("False Positives(actual=ham, predicted=spam) = {}".format(fp))
        print("False Negatives(actual=spam,predicted=ham) = {}".format(fn))
        print("Accuracy = {:.2f}%".format((tp+tn)/float(len(y_test))*100))
        print("Recall = {:.2f}%".format((tp/float(tp+fn))*100))
        print("Specificity = {:.2f}%".format((tn/float(tn+fp))*100))
        test_ham_count = len(test_df.loc[test_df["mail_label"]=="ham"])
        test_spam_count = len(test_df.loc[test_df["mail_label"]=="spam"])
        measure_after_iteration.loc[i] = [len(train_df.loc[train_df["mail_label"]=="spam"]),\
                                          len(train_df.loc[train_df["mail_label"]=="ham"]),\
                                          test_spam_count,test_ham_count,tn, fp, fn, tp,
                                          float(test_ham_count)/test_spam_count]
        
    measure_after_iteration["Recall"] = ((measure_after_iteration["True_positive"]/(measure_after_iteration["True_positive"]+
                                                                    measure_after_iteration["False_negative"]))*100.0)
    measure_after_iteration["Specificity"] = ((measure_after_iteration["True_negative"]/(measure_after_iteration["True_negative"]+
                                                                            measure_after_iteration["False_positive"]))*100.0)

    measure_after_iteration.to_csv("Res/processed_data/measure_after_iteration_"+enron_dataset+".csv",sep=",",index=False)
    attributes_hot_encoded_df.to_csv("Res/processed_data/attributes_hot_encoded_df_"+enron_dataset+".csv",sep=",",index=False)

    # Plotting the graphs for each simulation
    plt.close()
    plt.plot(range(2,len(measure_after_iteration)+1),measure_after_iteration["Recall"][1:],"-or")
    plt.plot(range(2,len(measure_after_iteration)+1),measure_after_iteration["Specificity"][1:],"-ob")
    plt.xlabel("Number of emails X 100")
    plt.legend(("Spam Recall","Ham Recall"),loc='lower right')
    plt.title(enron_dataset)
    plt.grid()
    plt.savefig("Res/processed_data/plot_simulation_"+enron_dataset+".jpg")

    plt.close()
    plt.plot(range(2,len(measure_after_iteration)+1),measure_after_iteration["ratio_per_batch"][1:],"-og")
    plt.xlabel("Batch Number")
    plt.title(enron_dataset+" - ham:spam ratio per batch")
    plt.grid()
    plt.savefig("Res/processed_data/plot_simulation_"+enron_dataset+"_fluctuation.jpg")
    print("Done !")
# Out:
# Running simulation for enron3...
# train = 100, test = 100
# /Users/gouravsanjuktabhabesh/.conda/envs/ml_101_env/lib/python2.7/site-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [0]	eval-auc:0.701143	train-auc:0.983279
# /Users/gouravsanjuktabhabesh/.conda/envs/ml_101_env/lib/python2.7/site-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gouravsanjuktabhabesh/.conda/envs/ml_101_env/lib/python2.7/site-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [1]	eval-auc:0.852911	train-auc:0.998904
# [2]	eval-auc:0.901507	train-auc:1
# [3]	eval-auc:0.942308	train-auc:1
# [4]	eval-auc:0.956341	train-auc:1
# [5]	eval-auc:0.955821	train-auc:1
# [6]	eval-auc:0.949584	train-auc:1
# [7]	eval-auc:0.948025	train-auc:1
# [8]	eval-auc:0.954262	train-auc:1
# [9]	eval-auc:0.948025	train-auc:1
# [10]	eval-auc:0.943867	train-auc:1
# [11]	eval-auc:0.945946	train-auc:1
# [12]	eval-auc:0.945426	train-auc:1
# [13]	eval-auc:0.948025	train-auc:1
# [14]	eval-auc:0.950104	train-auc:1
# [15]	eval-auc:0.950624	train-auc:1
# [16]	eval-auc:0.949584	train-auc:1
# [17]	eval-auc:0.952183	train-auc:1
# [18]	eval-auc:0.951143	train-auc:1
# [19]	eval-auc:0.952703	train-auc:1
# [20]	eval-auc:0.949584	train-auc:1
# [21]	eval-auc:0.949584	train-auc:1
# [22]	eval-auc:0.952183	train-auc:1
# [23]	eval-auc:0.950104	train-auc:1
# [24]	eval-auc:0.951663	train-auc:1
# [25]	eval-auc:0.952703	train-auc:1
# [26]	eval-auc:0.952703	train-auc:1
# [27]	eval-auc:0.952703	train-auc:1
# [28]	eval-auc:0.953742	train-auc:1
# [29]	eval-auc:0.954782	train-auc:1
# True Positives(spam) = 19
# True Negatives(ham)  = 70
# False Positives(actual=ham, predicted=spam) = 4
# False Negatives(actual=spam,predicted=ham) = 7
# Accuracy = 88.12%
# Recall = 73.08%
# Specificity = 94.59%
# train = 200, test = 100
# [0]	eval-auc:0.794133	train-auc:0.993267
# [1]	eval-auc:0.9056	train-auc:0.999333
# [2]	eval-auc:0.899467	train-auc:0.999867
# [3]	eval-auc:0.9336	train-auc:1
# [4]	eval-auc:0.934667	train-auc:1
# [5]	eval-auc:0.9432	train-auc:1
# [6]	eval-auc:0.942133	train-auc:1
# [7]	eval-auc:0.9376	train-auc:1
# [8]	eval-auc:0.937067	train-auc:1
# [9]	eval-auc:0.9384	train-auc:1
# [10]	eval-auc:0.931467	train-auc:1
# [11]	eval-auc:0.9344	train-auc:1
# [12]	eval-auc:0.933867	train-auc:1
# [13]	eval-auc:0.927467	train-auc:1
# [14]	eval-auc:0.933333	train-auc:1
# [15]	eval-auc:0.933333	train-auc:1
# [16]	eval-auc:0.936533	train-auc:1
# [17]	eval-auc:0.932267	train-auc:1
# [18]	eval-auc:0.933333	train-auc:1
# [19]	eval-auc:0.9376	train-auc:1
# [20]	eval-auc:0.9344	train-auc:1
# [21]	eval-auc:0.933867	train-auc:1
# [22]	eval-auc:0.936	train-auc:1
# [23]	eval-auc:0.932267	train-auc:1
# [24]	eval-auc:0.935467	train-auc:1
# [25]	eval-auc:0.936533	train-auc:1
# [26]	eval-auc:0.933867	train-auc:1
# [27]	eval-auc:0.931733	train-auc:1
# [28]	eval-auc:0.9328	train-auc:1
# [29]	eval-auc:0.9312	train-auc:1
# True Positives(spam) = 15
# True Negatives(ham)  = 74
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 10
# Accuracy = 88.12%
# Recall = 60.00%
# Specificity = 98.67%
# train = 300, test = 100
# [0]	eval-auc:0.732588	train-auc:0.991319
# [1]	eval-auc:0.844854	train-auc:0.999289
# [2]	eval-auc:0.87604	train-auc:0.999763
# [3]	eval-auc:0.908784	train-auc:0.999941
# [4]	eval-auc:0.934252	train-auc:0.999941
# [5]	eval-auc:0.946985	train-auc:0.999941
# [6]	eval-auc:0.951143	train-auc:0.999941
# [7]	eval-auc:0.953742	train-auc:0.999941
# [8]	eval-auc:0.9579	train-auc:1
# [9]	eval-auc:0.952183	train-auc:1
# [10]	eval-auc:0.953742	train-auc:1
# [11]	eval-auc:0.955301	train-auc:1
# [12]	eval-auc:0.951663	train-auc:1
# [13]	eval-auc:0.952703	train-auc:1
# [14]	eval-auc:0.955821	train-auc:1
# [15]	eval-auc:0.954262	train-auc:1
# [16]	eval-auc:0.948545	train-auc:1
# [17]	eval-auc:0.949064	train-auc:1
# [18]	eval-auc:0.948025	train-auc:1
# [19]	eval-auc:0.947505	train-auc:1
# [20]	eval-auc:0.944387	train-auc:1
# [21]	eval-auc:0.945426	train-auc:1
# [22]	eval-auc:0.944906	train-auc:1
# [23]	eval-auc:0.945426	train-auc:1
# [24]	eval-auc:0.941788	train-auc:1
# [25]	eval-auc:0.942827	train-auc:1
# [26]	eval-auc:0.940229	train-auc:1
# [27]	eval-auc:0.940229	train-auc:1
# [28]	eval-auc:0.941268	train-auc:1
# [29]	eval-auc:0.941788	train-auc:1
# True Positives(spam) = 17
# True Negatives(ham)  = 70
# False Positives(actual=ham, predicted=spam) = 4
# False Negatives(actual=spam,predicted=ham) = 9
# Accuracy = 86.14%
# Recall = 65.38%
# Specificity = 94.59%
# train = 400, test = 100
# [0]	eval-auc:0.933662	train-auc:0.992086
# [1]	eval-auc:0.971491	train-auc:0.99947
# [2]	eval-auc:0.979989	train-auc:1
# [3]	eval-auc:0.977522	train-auc:1
# [4]	eval-auc:0.983004	train-auc:1
# [5]	eval-auc:0.982456	train-auc:1
# [6]	eval-auc:0.981908	train-auc:1
# [7]	eval-auc:0.983004	train-auc:1
# [8]	eval-auc:0.981908	train-auc:1
# [9]	eval-auc:0.979715	train-auc:1
# [10]	eval-auc:0.979715	train-auc:1
# [11]	eval-auc:0.98136	train-auc:1
# [12]	eval-auc:0.980263	train-auc:1
# [13]	eval-auc:0.980263	train-auc:1
# [14]	eval-auc:0.981908	train-auc:1
# [15]	eval-auc:0.980263	train-auc:1
# [16]	eval-auc:0.98136	train-auc:1
# [17]	eval-auc:0.98136	train-auc:1
# [18]	eval-auc:0.980811	train-auc:1
# [19]	eval-auc:0.980811	train-auc:1
# [20]	eval-auc:0.981908	train-auc:1
# [21]	eval-auc:0.983004	train-auc:1
# [22]	eval-auc:0.983004	train-auc:1
# [23]	eval-auc:0.98136	train-auc:1
# [24]	eval-auc:0.980263	train-auc:1
# [25]	eval-auc:0.979715	train-auc:1
# [26]	eval-auc:0.980263	train-auc:1
# [27]	eval-auc:0.980811	train-auc:1
# [28]	eval-auc:0.979715	train-auc:1
# [29]	eval-auc:0.980263	train-auc:1
# True Positives(spam) = 18
# True Negatives(ham)  = 74
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 6
# Accuracy = 91.09%
# Recall = 75.00%
# Specificity = 97.37%
# train = 500, test = 100
# [0]	eval-auc:0.950364	train-auc:0.995403
# [1]	eval-auc:0.985447	train-auc:0.999893
# [2]	eval-auc:0.986486	train-auc:1
# [3]	eval-auc:0.986486	train-auc:1
# [4]	eval-auc:0.988566	train-auc:1
# [5]	eval-auc:0.992204	train-auc:1
# [6]	eval-auc:0.991164	train-auc:1
# [7]	eval-auc:0.994283	train-auc:1
# [8]	eval-auc:0.995322	train-auc:1
# [9]	eval-auc:0.995322	train-auc:1
# [10]	eval-auc:0.995842	train-auc:1
# [11]	eval-auc:0.995842	train-auc:1
# [12]	eval-auc:0.995322	train-auc:1
# [13]	eval-auc:0.995842	train-auc:1
# [14]	eval-auc:0.995842	train-auc:1
# [15]	eval-auc:0.996362	train-auc:1
# [16]	eval-auc:0.997401	train-auc:1
# [17]	eval-auc:0.996881	train-auc:1
# [18]	eval-auc:0.996362	train-auc:1
# [19]	eval-auc:0.996881	train-auc:1
# [20]	eval-auc:0.996881	train-auc:1
# [21]	eval-auc:0.996881	train-auc:1
# [22]	eval-auc:0.997401	train-auc:1
# [23]	eval-auc:0.997921	train-auc:1
# [24]	eval-auc:0.997921	train-auc:1
# [25]	eval-auc:0.997921	train-auc:1
# [26]	eval-auc:0.997401	train-auc:1
# [27]	eval-auc:0.996881	train-auc:1
# [28]	eval-auc:0.996881	train-auc:1
# [29]	eval-auc:0.996881	train-auc:1
# True Positives(spam) = 25
# True Negatives(ham)  = 72
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 96.04%
# Recall = 96.15%
# Specificity = 97.30%
# train = 600, test = 100
# [0]	eval-auc:0.917541	train-auc:0.995155
# [1]	eval-auc:0.963287	train-auc:0.999794
# [2]	eval-auc:0.977273	train-auc:1
# [3]	eval-auc:0.977856	train-auc:1
# [4]	eval-auc:0.980769	train-auc:1
# [5]	eval-auc:0.983683	train-auc:1
# [6]	eval-auc:0.986014	train-auc:1
# [7]	eval-auc:0.986014	train-auc:1
# [8]	eval-auc:0.986597	train-auc:1
# [9]	eval-auc:0.984266	train-auc:1
# [10]	eval-auc:0.984266	train-auc:1
# [11]	eval-auc:0.983683	train-auc:1
# [12]	eval-auc:0.983683	train-auc:1
# [13]	eval-auc:0.981935	train-auc:1
# [14]	eval-auc:0.980186	train-auc:1
# [15]	eval-auc:0.984848	train-auc:1
# [16]	eval-auc:0.983683	train-auc:1
# [17]	eval-auc:0.984848	train-auc:1
# [18]	eval-auc:0.983683	train-auc:1
# [19]	eval-auc:0.982517	train-auc:1
# [20]	eval-auc:0.981935	train-auc:1
# [21]	eval-auc:0.980769	train-auc:1
# [22]	eval-auc:0.980769	train-auc:1
# [23]	eval-auc:0.979604	train-auc:1
# [24]	eval-auc:0.980769	train-auc:1
# [25]	eval-auc:0.981352	train-auc:1
# [26]	eval-auc:0.981352	train-auc:1
# [27]	eval-auc:0.981352	train-auc:1
# [28]	eval-auc:0.980186	train-auc:1
# [29]	eval-auc:0.978438	train-auc:1
# True Positives(spam) = 18
# True Negatives(ham)  = 76
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 4
# Accuracy = 93.07%
# Recall = 81.82%
# Specificity = 97.44%
# train = 700, test = 100
# [0]	eval-auc:0.9552	train-auc:0.996221
# [1]	eval-auc:0.9808	train-auc:0.999989
# [2]	eval-auc:0.9872	train-auc:0.999989
# [3]	eval-auc:0.9752	train-auc:1
# [4]	eval-auc:0.979467	train-auc:1
# [5]	eval-auc:0.976267	train-auc:1
# [6]	eval-auc:0.9768	train-auc:1
# [7]	eval-auc:0.9824	train-auc:1
# [8]	eval-auc:0.984	train-auc:1
# [9]	eval-auc:0.9824	train-auc:1
# [10]	eval-auc:0.9808	train-auc:1
# [11]	eval-auc:0.983467	train-auc:1
# [12]	eval-auc:0.983467	train-auc:1
# [13]	eval-auc:0.983467	train-auc:1
# [14]	eval-auc:0.983467	train-auc:1
# [15]	eval-auc:0.984	train-auc:1
# [16]	eval-auc:0.984533	train-auc:1
# [17]	eval-auc:0.9856	train-auc:1
# [18]	eval-auc:0.986667	train-auc:1
# [19]	eval-auc:0.9872	train-auc:1
# [20]	eval-auc:0.986133	train-auc:1
# [21]	eval-auc:0.986133	train-auc:1
# [22]	eval-auc:0.986133	train-auc:1
# [23]	eval-auc:0.988267	train-auc:1
# [24]	eval-auc:0.9872	train-auc:1
# [25]	eval-auc:0.987733	train-auc:1
# [26]	eval-auc:0.9872	train-auc:1
# [27]	eval-auc:0.988267	train-auc:1
# [28]	eval-auc:0.988267	train-auc:1
# [29]	eval-auc:0.986667	train-auc:1
# True Positives(spam) = 23
# True Negatives(ham)  = 75
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 97.03%
# Recall = 92.00%
# Specificity = 100.00%
# train = 800, test = 100
# [0]	eval-auc:0.9232	train-auc:0.997265
# [1]	eval-auc:0.9888	train-auc:0.999841
# [2]	eval-auc:0.994933	train-auc:1
# [3]	eval-auc:0.995467	train-auc:1
# [4]	eval-auc:0.996533	train-auc:1
# [5]	eval-auc:0.996533	train-auc:1
# [6]	eval-auc:0.9952	train-auc:1
# [7]	eval-auc:0.9968	train-auc:1
# [8]	eval-auc:0.9968	train-auc:1
# [9]	eval-auc:0.997867	train-auc:1
# [10]	eval-auc:0.998933	train-auc:1
# [11]	eval-auc:0.9984	train-auc:1
# [12]	eval-auc:0.9984	train-auc:1
# [13]	eval-auc:0.997867	train-auc:1
# [14]	eval-auc:1	train-auc:1
# [15]	eval-auc:0.997867	train-auc:1
# [16]	eval-auc:0.997867	train-auc:1
# [17]	eval-auc:0.998933	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:0.9984	train-auc:1
# [22]	eval-auc:0.998933	train-auc:1
# [23]	eval-auc:0.998933	train-auc:1
# [24]	eval-auc:0.998933	train-auc:1
# [25]	eval-auc:0.999467	train-auc:1
# [26]	eval-auc:0.998933	train-auc:1
# [27]	eval-auc:0.999467	train-auc:1
# [28]	eval-auc:1	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 23
# True Negatives(ham)  = 75
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 97.03%
# Recall = 92.00%
# Specificity = 100.00%
# train = 900, test = 100
# [0]	eval-auc:0.91502	train-auc:0.995237
# [1]	eval-auc:0.899209	train-auc:0.999914
# [2]	eval-auc:0.953981	train-auc:1
# [3]	eval-auc:0.94664	train-auc:1
# [4]	eval-auc:0.966685	train-auc:1
# [5]	eval-auc:0.971203	train-auc:1
# [6]	eval-auc:0.972897	train-auc:1
# [7]	eval-auc:0.979108	train-auc:1
# [8]	eval-auc:0.973461	train-auc:1
# [9]	eval-auc:0.969509	train-auc:1
# [10]	eval-auc:0.974591	train-auc:1
# [11]	eval-auc:0.972332	train-auc:1
# [12]	eval-auc:0.973461	train-auc:1
# [13]	eval-auc:0.975155	train-auc:1
# [14]	eval-auc:0.972897	train-auc:1
# [15]	eval-auc:0.970073	train-auc:1
# [16]	eval-auc:0.972897	train-auc:1
# [17]	eval-auc:0.972897	train-auc:1
# [18]	eval-auc:0.970073	train-auc:1
# [19]	eval-auc:0.972332	train-auc:1
# [20]	eval-auc:0.968379	train-auc:1
# [21]	eval-auc:0.970073	train-auc:1
# [22]	eval-auc:0.971767	train-auc:1
# [23]	eval-auc:0.971203	train-auc:1
# [24]	eval-auc:0.971767	train-auc:1
# [25]	eval-auc:0.974026	train-auc:1
# [26]	eval-auc:0.972332	train-auc:1
# [27]	eval-auc:0.973461	train-auc:1
# [28]	eval-auc:0.974026	train-auc:1
# [29]	eval-auc:0.971767	train-auc:1
# True Positives(spam) = 20
# True Negatives(ham)  = 76
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 3
# Accuracy = 95.05%
# Recall = 86.96%
# Specificity = 98.70%
# train = 1000, test = 100
# [0]	eval-auc:0.918893	train-auc:0.996571
# [1]	eval-auc:0.968674	train-auc:0.999865
# [2]	eval-auc:0.978145	train-auc:0.999997
# [3]	eval-auc:0.979116	train-auc:1
# [4]	eval-auc:0.98203	train-auc:1
# [5]	eval-auc:0.980573	train-auc:1
# [6]	eval-auc:0.98203	train-auc:1
# [7]	eval-auc:0.981544	train-auc:1
# [8]	eval-auc:0.985915	train-auc:1
# [9]	eval-auc:0.986887	train-auc:1
# [10]	eval-auc:0.986401	train-auc:1
# [11]	eval-auc:0.985915	train-auc:1
# [12]	eval-auc:0.98543	train-auc:1
# [13]	eval-auc:0.988344	train-auc:1
# [14]	eval-auc:0.986887	train-auc:1
# [15]	eval-auc:0.985915	train-auc:1
# [16]	eval-auc:0.986401	train-auc:1
# [17]	eval-auc:0.987373	train-auc:1
# [18]	eval-auc:0.986401	train-auc:1
# [19]	eval-auc:0.98543	train-auc:1
# [20]	eval-auc:0.986401	train-auc:1
# [21]	eval-auc:0.986401	train-auc:1
# [22]	eval-auc:0.987858	train-auc:1
# [23]	eval-auc:0.987373	train-auc:1
# [24]	eval-auc:0.987373	train-auc:1
# [25]	eval-auc:0.986401	train-auc:1
# [26]	eval-auc:0.986887	train-auc:1
# [27]	eval-auc:0.984944	train-auc:1
# [28]	eval-auc:0.98543	train-auc:1
# [29]	eval-auc:0.98543	train-auc:1
# True Positives(spam) = 25
# True Negatives(ham)  = 68
# False Positives(actual=ham, predicted=spam) = 3
# False Negatives(actual=spam,predicted=ham) = 4
# Accuracy = 92.08%
# Recall = 86.21%
# Specificity = 95.77%
# train = 1100, test = 100
# [0]	eval-auc:0.926595	train-auc:0.996826
# [1]	eval-auc:0.959627	train-auc:0.999905
# [2]	eval-auc:0.981084	train-auc:0.999996
# [3]	eval-auc:0.981649	train-auc:1
# [4]	eval-auc:0.986448	train-auc:1
# [5]	eval-auc:0.985884	train-auc:1
# [6]	eval-auc:0.987578	train-auc:1
# [7]	eval-auc:0.988707	train-auc:1
# [8]	eval-auc:0.989272	train-auc:1
# [9]	eval-auc:0.990401	train-auc:1
# [10]	eval-auc:0.990966	train-auc:1
# [11]	eval-auc:0.99153	train-auc:1
# [12]	eval-auc:0.990966	train-auc:1
# [13]	eval-auc:0.99153	train-auc:1
# [14]	eval-auc:0.990966	train-auc:1
# [15]	eval-auc:0.990401	train-auc:1
# [16]	eval-auc:0.990401	train-auc:1
# [17]	eval-auc:0.990966	train-auc:1
# [18]	eval-auc:0.990401	train-auc:1
# [19]	eval-auc:0.990966	train-auc:1
# [20]	eval-auc:0.990966	train-auc:1
# [21]	eval-auc:0.990401	train-auc:1
# [22]	eval-auc:0.990401	train-auc:1
# [23]	eval-auc:0.989836	train-auc:1
# [24]	eval-auc:0.990401	train-auc:1
# [25]	eval-auc:0.989836	train-auc:1
# [26]	eval-auc:0.990401	train-auc:1
# [27]	eval-auc:0.990401	train-auc:1
# [28]	eval-auc:0.990401	train-auc:1
# [29]	eval-auc:0.989836	train-auc:1
# True Positives(spam) = 20
# True Negatives(ham)  = 73
# False Positives(actual=ham, predicted=spam) = 4
# False Negatives(actual=spam,predicted=ham) = 3
# Accuracy = 92.08%
# Recall = 86.96%
# Specificity = 94.81%
# train = 1200, test = 100
# [0]	eval-auc:0.935058	train-auc:0.997584
# [1]	eval-auc:0.95307	train-auc:0.99998
# [2]	eval-auc:0.980213	train-auc:1
# [3]	eval-auc:0.972095	train-auc:1
# [4]	eval-auc:0.978691	train-auc:1
# [5]	eval-auc:0.98072	train-auc:1
# [6]	eval-auc:0.985287	train-auc:1
# [7]	eval-auc:0.98275	train-auc:1
# [8]	eval-auc:0.983765	train-auc:1
# [9]	eval-auc:0.984779	train-auc:1
# [10]	eval-auc:0.986809	train-auc:1
# [11]	eval-auc:0.988838	train-auc:1
# [12]	eval-auc:0.988838	train-auc:1
# [13]	eval-auc:0.987316	train-auc:1
# [14]	eval-auc:0.985287	train-auc:1
# [15]	eval-auc:0.986301	train-auc:1
# [16]	eval-auc:0.987316	train-auc:1
# [17]	eval-auc:0.988838	train-auc:1
# [18]	eval-auc:0.987316	train-auc:1
# [19]	eval-auc:0.986301	train-auc:1
# [20]	eval-auc:0.987316	train-auc:1
# [21]	eval-auc:0.987823	train-auc:1
# [22]	eval-auc:0.987823	train-auc:1
# [23]	eval-auc:0.989345	train-auc:1
# [24]	eval-auc:0.989345	train-auc:1
# [25]	eval-auc:0.989345	train-auc:1
# [26]	eval-auc:0.988838	train-auc:1
# [27]	eval-auc:0.989345	train-auc:1
# [28]	eval-auc:0.989345	train-auc:1
# [29]	eval-auc:0.989345	train-auc:1
# True Positives(spam) = 26
# True Negatives(ham)  = 70
# False Positives(actual=ham, predicted=spam) = 3
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 95.05%
# Recall = 96.30%
# Specificity = 95.89%
# train = 1300, test = 100
# [0]	eval-auc:0.990385	train-auc:0.996046
# [1]	eval-auc:0.969595	train-auc:0.999814
# [2]	eval-auc:0.993243	train-auc:0.999997
# [3]	eval-auc:0.990125	train-auc:1
# [4]	eval-auc:0.987006	train-auc:1
# [5]	eval-auc:0.988566	train-auc:1
# [6]	eval-auc:0.992723	train-auc:1
# [7]	eval-auc:0.993763	train-auc:1
# [8]	eval-auc:0.992204	train-auc:1
# [9]	eval-auc:0.995322	train-auc:1
# [10]	eval-auc:0.995322	train-auc:1
# [11]	eval-auc:0.996881	train-auc:1
# [12]	eval-auc:0.997921	train-auc:1
# [13]	eval-auc:0.996881	train-auc:1
# [14]	eval-auc:0.996362	train-auc:1
# [15]	eval-auc:0.997401	train-auc:1
# [16]	eval-auc:0.998441	train-auc:1
# [17]	eval-auc:0.998441	train-auc:1
# [18]	eval-auc:0.998441	train-auc:1
# [19]	eval-auc:0.998441	train-auc:1
# [20]	eval-auc:0.99896	train-auc:1
# [21]	eval-auc:0.998441	train-auc:1
# [22]	eval-auc:0.998441	train-auc:1
# [23]	eval-auc:0.998441	train-auc:1
# [24]	eval-auc:0.998441	train-auc:1
# [25]	eval-auc:0.998441	train-auc:1
# [26]	eval-auc:0.99948	train-auc:1
# [27]	eval-auc:0.998441	train-auc:1
# [28]	eval-auc:0.998441	train-auc:1
# [29]	eval-auc:0.998441	train-auc:1
# True Positives(spam) = 21
# True Negatives(ham)  = 74
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 5
# Accuracy = 94.06%
# Recall = 80.77%
# Specificity = 100.00%
# train = 1400, test = 100
# [0]	eval-auc:0.958933	train-auc:0.996354
# [1]	eval-auc:0.974133	train-auc:0.99976
# [2]	eval-auc:0.9752	train-auc:1
# [3]	eval-auc:0.9744	train-auc:1
# [4]	eval-auc:0.978667	train-auc:1
# [5]	eval-auc:0.9808	train-auc:1
# [6]	eval-auc:0.9824	train-auc:1
# [7]	eval-auc:0.983467	train-auc:1
# [8]	eval-auc:0.986133	train-auc:1
# [9]	eval-auc:0.9888	train-auc:1
# [10]	eval-auc:0.989867	train-auc:1
# [11]	eval-auc:0.988267	train-auc:1
# [12]	eval-auc:0.9888	train-auc:1
# [13]	eval-auc:0.988267	train-auc:1
# [14]	eval-auc:0.988267	train-auc:1
# [15]	eval-auc:0.989333	train-auc:1
# [16]	eval-auc:0.989333	train-auc:1
# [17]	eval-auc:0.989333	train-auc:1
# [18]	eval-auc:0.989333	train-auc:1
# [19]	eval-auc:0.9888	train-auc:1
# [20]	eval-auc:0.988267	train-auc:1
# [21]	eval-auc:0.9888	train-auc:1
# [22]	eval-auc:0.9888	train-auc:1
# [23]	eval-auc:0.9888	train-auc:1
# [24]	eval-auc:0.9888	train-auc:1
# [25]	eval-auc:0.9888	train-auc:1
# [26]	eval-auc:0.9888	train-auc:1
# [27]	eval-auc:0.989333	train-auc:1
# [28]	eval-auc:0.9888	train-auc:1
# [29]	eval-auc:0.989333	train-auc:1
# True Positives(spam) = 24
# True Negatives(ham)  = 71
# False Positives(actual=ham, predicted=spam) = 4
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 94.06%
# Recall = 96.00%
# Specificity = 94.67%
# train = 1500, test = 100
# [0]	eval-auc:0.980811	train-auc:0.996453
# [1]	eval-auc:0.997807	train-auc:0.999749
# [2]	eval-auc:0.997259	train-auc:0.999998
# [3]	eval-auc:0.999452	train-auc:1
# [4]	eval-auc:0.996711	train-auc:1
# [5]	eval-auc:0.996711	train-auc:1
# [6]	eval-auc:0.997807	train-auc:1
# [7]	eval-auc:0.997807	train-auc:1
# [8]	eval-auc:0.998904	train-auc:1
# [9]	eval-auc:0.998904	train-auc:1
# [10]	eval-auc:0.998904	train-auc:1
# [11]	eval-auc:0.998904	train-auc:1
# [12]	eval-auc:0.998904	train-auc:1
# [13]	eval-auc:0.998904	train-auc:1
# [14]	eval-auc:0.998904	train-auc:1
# [15]	eval-auc:0.998904	train-auc:1
# [16]	eval-auc:0.999452	train-auc:1
# [17]	eval-auc:0.999452	train-auc:1
# [18]	eval-auc:0.998904	train-auc:1
# [19]	eval-auc:0.999452	train-auc:1
# [20]	eval-auc:0.999452	train-auc:1
# [21]	eval-auc:0.999452	train-auc:1
# [22]	eval-auc:0.999452	train-auc:1
# [23]	eval-auc:0.999452	train-auc:1
# [24]	eval-auc:0.999452	train-auc:1
# [25]	eval-auc:0.999452	train-auc:1
# [26]	eval-auc:0.999452	train-auc:1
# [27]	eval-auc:0.999452	train-auc:1
# [28]	eval-auc:0.999452	train-auc:1
# [29]	eval-auc:0.999452	train-auc:1
# True Positives(spam) = 22
# True Negatives(ham)  = 76
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 97.03%
# Recall = 91.67%
# Specificity = 100.00%
# train = 1600, test = 100
# [0]	eval-auc:0.997378	train-auc:0.99749
# [1]	eval-auc:1	train-auc:0.999805
# [2]	eval-auc:1	train-auc:0.999996
# [3]	eval-auc:0.999417	train-auc:1
# [4]	eval-auc:1	train-auc:1
# [5]	eval-auc:0.999417	train-auc:1
# [6]	eval-auc:0.999417	train-auc:1
# [7]	eval-auc:0.999417	train-auc:1
# [8]	eval-auc:0.999417	train-auc:1
# [9]	eval-auc:0.999417	train-auc:1
# [10]	eval-auc:0.999417	train-auc:1
# [11]	eval-auc:0.999417	train-auc:1
# [12]	eval-auc:0.999417	train-auc:1
# [13]	eval-auc:0.999417	train-auc:1
# [14]	eval-auc:0.999417	train-auc:1
# [15]	eval-auc:0.999417	train-auc:1
# [16]	eval-auc:0.999417	train-auc:1
# [17]	eval-auc:0.999417	train-auc:1
# [18]	eval-auc:0.999417	train-auc:1
# [19]	eval-auc:0.999417	train-auc:1
# [20]	eval-auc:0.999417	train-auc:1
# [21]	eval-auc:0.999417	train-auc:1
# [22]	eval-auc:0.999417	train-auc:1
# [23]	eval-auc:0.999417	train-auc:1
# [24]	eval-auc:0.999417	train-auc:1
# [25]	eval-auc:0.999417	train-auc:1
# [26]	eval-auc:0.999417	train-auc:1
# [27]	eval-auc:0.999417	train-auc:1
# [28]	eval-auc:0.999417	train-auc:1
# [29]	eval-auc:0.999417	train-auc:1
# True Positives(spam) = 21
# True Negatives(ham)  = 77
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 97.03%
# Recall = 95.45%
# Specificity = 98.72%
# train = 1700, test = 100
# [0]	eval-auc:0.995467	train-auc:0.996684
# [1]	eval-auc:0.997333	train-auc:0.999669
# [2]	eval-auc:0.998933	train-auc:0.999965
# [3]	eval-auc:0.997867	train-auc:0.999998
# [4]	eval-auc:0.997867	train-auc:1
# [5]	eval-auc:0.997333	train-auc:1
# [6]	eval-auc:0.997333	train-auc:1
# [7]	eval-auc:0.997867	train-auc:1
# [8]	eval-auc:0.997867	train-auc:1
# [9]	eval-auc:0.997333	train-auc:1
# [10]	eval-auc:0.9968	train-auc:1
# [11]	eval-auc:0.997333	train-auc:1
# [12]	eval-auc:0.997333	train-auc:1
# [13]	eval-auc:0.997333	train-auc:1
# [14]	eval-auc:0.997333	train-auc:1
# [15]	eval-auc:0.997333	train-auc:1
# [16]	eval-auc:0.9968	train-auc:1
# [17]	eval-auc:0.9968	train-auc:1
# [18]	eval-auc:0.9968	train-auc:1
# [19]	eval-auc:0.9968	train-auc:1
# [20]	eval-auc:0.9968	train-auc:1
# [21]	eval-auc:0.9968	train-auc:1
# [22]	eval-auc:0.996267	train-auc:1
# [23]	eval-auc:0.9968	train-auc:1
# [24]	eval-auc:0.9968	train-auc:1
# [25]	eval-auc:0.9968	train-auc:1
# [26]	eval-auc:0.9968	train-auc:1
# [27]	eval-auc:0.9968	train-auc:1
# [28]	eval-auc:0.9968	train-auc:1
# [29]	eval-auc:0.9968	train-auc:1
# True Positives(spam) = 23
# True Negatives(ham)  = 73
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 95.05%
# Recall = 92.00%
# Specificity = 97.33%
# train = 1800, test = 100
# [0]	eval-auc:0.988547	train-auc:0.996982
# [1]	eval-auc:0.996383	train-auc:0.999622
# [2]	eval-auc:0.996986	train-auc:0.999974
# [3]	eval-auc:0.998794	train-auc:1
# [4]	eval-auc:0.999397	train-auc:1
# [5]	eval-auc:0.998794	train-auc:1
# [6]	eval-auc:0.999397	train-auc:1
# [7]	eval-auc:1	train-auc:1
# [8]	eval-auc:1	train-auc:1
# [9]	eval-auc:1	train-auc:1
# [10]	eval-auc:1	train-auc:1
# [11]	eval-auc:1	train-auc:1
# [12]	eval-auc:1	train-auc:1
# [13]	eval-auc:1	train-auc:1
# [14]	eval-auc:1	train-auc:1
# [15]	eval-auc:1	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:1	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:1	train-auc:1
# [22]	eval-auc:1	train-auc:1
# [23]	eval-auc:1	train-auc:1
# [24]	eval-auc:1	train-auc:1
# [25]	eval-auc:1	train-auc:1
# [26]	eval-auc:1	train-auc:1
# [27]	eval-auc:1	train-auc:1
# [28]	eval-auc:1	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 19
# True Negatives(ham)  = 79
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 97.03%
# Recall = 90.48%
# Specificity = 100.00%
# train = 1900, test = 100
# [0]	eval-auc:0.99948	train-auc:0.997101
# [1]	eval-auc:0.998441	train-auc:0.999856
# [2]	eval-auc:1	train-auc:0.999997
# [3]	eval-auc:1	train-auc:1
# [4]	eval-auc:1	train-auc:1
# [5]	eval-auc:1	train-auc:1
# [6]	eval-auc:1	train-auc:1
# [7]	eval-auc:1	train-auc:1
# [8]	eval-auc:1	train-auc:1
# [9]	eval-auc:1	train-auc:1
# [10]	eval-auc:1	train-auc:1
# [11]	eval-auc:1	train-auc:1
# [12]	eval-auc:1	train-auc:1
# [13]	eval-auc:1	train-auc:1
# [14]	eval-auc:1	train-auc:1
# [15]	eval-auc:1	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:1	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:1	train-auc:1
# [22]	eval-auc:1	train-auc:1
# [23]	eval-auc:1	train-auc:1
# [24]	eval-auc:1	train-auc:1
# [25]	eval-auc:1	train-auc:1
# [26]	eval-auc:1	train-auc:1
# [27]	eval-auc:1	train-auc:1
# [28]	eval-auc:1	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 23
# True Negatives(ham)  = 74
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 3
# Accuracy = 96.04%
# Recall = 88.46%
# Specificity = 100.00%
# train = 2000, test = 100
# [0]	eval-auc:0.97921	train-auc:0.997179
# [1]	eval-auc:0.996362	train-auc:0.99971
# [2]	eval-auc:0.997921	train-auc:0.999974
# [3]	eval-auc:0.998441	train-auc:1
# [4]	eval-auc:0.99896	train-auc:1
# [5]	eval-auc:0.99896	train-auc:1
# [6]	eval-auc:0.99896	train-auc:1
# [7]	eval-auc:0.99896	train-auc:1
# [8]	eval-auc:0.99896	train-auc:1
# [9]	eval-auc:0.99948	train-auc:1
# [10]	eval-auc:0.99896	train-auc:1
# [11]	eval-auc:0.998441	train-auc:1
# [12]	eval-auc:1	train-auc:1
# [13]	eval-auc:0.99896	train-auc:1
# [14]	eval-auc:0.99948	train-auc:1
# [15]	eval-auc:0.99896	train-auc:1
# [16]	eval-auc:0.99948	train-auc:1
# [17]	eval-auc:0.99948	train-auc:1
# [18]	eval-auc:0.99948	train-auc:1
# [19]	eval-auc:0.99896	train-auc:1
# [20]	eval-auc:0.998441	train-auc:1
# [21]	eval-auc:0.997921	train-auc:1
# [22]	eval-auc:0.998441	train-auc:1
# [23]	eval-auc:0.998441	train-auc:1
# [24]	eval-auc:0.998441	train-auc:1
# [25]	eval-auc:0.998441	train-auc:1
# [26]	eval-auc:0.998441	train-auc:1
# [27]	eval-auc:0.997921	train-auc:1
# [28]	eval-auc:0.997921	train-auc:1
# [29]	eval-auc:0.997921	train-auc:1
# True Positives(spam) = 25
# True Negatives(ham)  = 74
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 98.02%
# Recall = 96.15%
# Specificity = 100.00%
# train = 2100, test = 100
# [0]	eval-auc:0.986667	train-auc:0.997546
# [1]	eval-auc:0.9968	train-auc:0.999861
# [2]	eval-auc:0.996267	train-auc:0.999957
# [3]	eval-auc:0.997333	train-auc:0.999996
# [4]	eval-auc:0.999467	train-auc:0.999999
# [5]	eval-auc:0.998933	train-auc:1
# [6]	eval-auc:0.998933	train-auc:1
# [7]	eval-auc:0.998933	train-auc:1
# [8]	eval-auc:0.998933	train-auc:1
# [9]	eval-auc:0.999467	train-auc:1
# [10]	eval-auc:0.999467	train-auc:1
# [11]	eval-auc:0.999467	train-auc:1
# [12]	eval-auc:0.999467	train-auc:1
# [13]	eval-auc:0.999467	train-auc:1
# [14]	eval-auc:0.998933	train-auc:1
# [15]	eval-auc:0.999467	train-auc:1
# [16]	eval-auc:0.998933	train-auc:1
# [17]	eval-auc:0.999467	train-auc:1
# [18]	eval-auc:0.999467	train-auc:1
# [19]	eval-auc:0.999467	train-auc:1
# [20]	eval-auc:0.999467	train-auc:1
# [21]	eval-auc:0.999467	train-auc:1
# [22]	eval-auc:0.999467	train-auc:1
# [23]	eval-auc:0.999467	train-auc:1
# [24]	eval-auc:0.999467	train-auc:1
# [25]	eval-auc:0.999467	train-auc:1
# [26]	eval-auc:0.999467	train-auc:1
# [27]	eval-auc:0.999467	train-auc:1
# [28]	eval-auc:0.999467	train-auc:1
# [29]	eval-auc:0.999467	train-auc:1
# True Positives(spam) = 22
# True Negatives(ham)  = 75
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 3
# Accuracy = 96.04%
# Recall = 88.00%
# Specificity = 100.00%
# train = 2200, test = 100
# [0]	eval-auc:0.9968	train-auc:0.997536
# [1]	eval-auc:0.9952	train-auc:0.999906
# [2]	eval-auc:0.997333	train-auc:0.999992
# [3]	eval-auc:0.997333	train-auc:1
# [4]	eval-auc:0.996267	train-auc:1
# [5]	eval-auc:0.996267	train-auc:1
# [6]	eval-auc:0.996267	train-auc:1
# [7]	eval-auc:0.997867	train-auc:1
# [8]	eval-auc:0.997867	train-auc:1
# [9]	eval-auc:0.997867	train-auc:1
# [10]	eval-auc:0.997867	train-auc:1
# [11]	eval-auc:0.997333	train-auc:1
# [12]	eval-auc:0.9968	train-auc:1
# [13]	eval-auc:0.997333	train-auc:1
# [14]	eval-auc:0.9968	train-auc:1
# [15]	eval-auc:0.9968	train-auc:1
# [16]	eval-auc:0.9968	train-auc:1
# [17]	eval-auc:0.997867	train-auc:1
# [18]	eval-auc:0.996267	train-auc:1
# [19]	eval-auc:0.9968	train-auc:1
# [20]	eval-auc:0.9968	train-auc:1
# [21]	eval-auc:0.995733	train-auc:1
# [22]	eval-auc:0.994667	train-auc:1
# [23]	eval-auc:0.995733	train-auc:1
# [24]	eval-auc:0.996267	train-auc:1
# [25]	eval-auc:0.996267	train-auc:1
# [26]	eval-auc:0.996267	train-auc:1
# [27]	eval-auc:0.996267	train-auc:1
# [28]	eval-auc:0.996267	train-auc:1
# [29]	eval-auc:0.996267	train-auc:1
# True Positives(spam) = 24
# True Negatives(ham)  = 74
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 97.03%
# Recall = 96.00%
# Specificity = 98.67%
# train = 2300, test = 100
# [0]	eval-auc:0.986014	train-auc:0.997375
# [1]	eval-auc:0.998252	train-auc:0.999811
# [2]	eval-auc:0.998834	train-auc:0.999985
# [3]	eval-auc:0.997669	train-auc:0.999999
# [4]	eval-auc:0.997669	train-auc:1
# [5]	eval-auc:0.997669	train-auc:1
# [6]	eval-auc:1	train-auc:1
# [7]	eval-auc:1	train-auc:1
# [8]	eval-auc:0.998834	train-auc:1
# [9]	eval-auc:0.998834	train-auc:1
# [10]	eval-auc:0.998834	train-auc:1
# [11]	eval-auc:0.998834	train-auc:1
# [12]	eval-auc:1	train-auc:1
# [13]	eval-auc:0.998834	train-auc:1
# [14]	eval-auc:1	train-auc:1
# [15]	eval-auc:1	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:1	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:0.998834	train-auc:1
# [22]	eval-auc:0.998834	train-auc:1
# [23]	eval-auc:0.998834	train-auc:1
# [24]	eval-auc:0.998834	train-auc:1
# [25]	eval-auc:0.998834	train-auc:1
# [26]	eval-auc:1	train-auc:1
# [27]	eval-auc:1	train-auc:1
# [28]	eval-auc:0.998834	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 21
# True Negatives(ham)  = 78
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 98.02%
# Recall = 95.45%
# Specificity = 100.00%
# train = 2400, test = 100
# [0]	eval-auc:0.989857	train-auc:0.997684
# [1]	eval-auc:0.998081	train-auc:0.999615
# [2]	eval-auc:0.999452	train-auc:0.999963
# [3]	eval-auc:0.999452	train-auc:0.999998
# [4]	eval-auc:0.998904	train-auc:1
# [5]	eval-auc:0.999452	train-auc:1
# [6]	eval-auc:0.999452	train-auc:1
# [7]	eval-auc:1	train-auc:1
# [8]	eval-auc:1	train-auc:1
# [9]	eval-auc:1	train-auc:1
# [10]	eval-auc:1	train-auc:1
# [11]	eval-auc:1	train-auc:1
# [12]	eval-auc:1	train-auc:1
# [13]	eval-auc:1	train-auc:1
# [14]	eval-auc:1	train-auc:1
# [15]	eval-auc:1	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:1	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:1	train-auc:1
# [22]	eval-auc:1	train-auc:1
# [23]	eval-auc:1	train-auc:1
# [24]	eval-auc:1	train-auc:1
# [25]	eval-auc:1	train-auc:1
# [26]	eval-auc:1	train-auc:1
# [27]	eval-auc:1	train-auc:1
# [28]	eval-auc:1	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 24
# True Negatives(ham)  = 76
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 99.01%
# Recall = 100.00%
# Specificity = 100.00%
# train = 2500, test = 100
# [0]	eval-auc:0.996528	train-auc:0.998013
# [1]	eval-auc:1	train-auc:0.999533
# [2]	eval-auc:1	train-auc:0.999957
# [3]	eval-auc:0.999008	train-auc:0.99999
# [4]	eval-auc:0.999504	train-auc:0.999999
# [5]	eval-auc:0.99752	train-auc:1
# [6]	eval-auc:0.996528	train-auc:1
# [7]	eval-auc:0.99752	train-auc:1
# [8]	eval-auc:0.999008	train-auc:1
# [9]	eval-auc:0.999008	train-auc:1
# [10]	eval-auc:0.999008	train-auc:1
# [11]	eval-auc:0.997024	train-auc:1
# [12]	eval-auc:0.999008	train-auc:1
# [13]	eval-auc:0.998016	train-auc:1
# [14]	eval-auc:0.996032	train-auc:1
# [15]	eval-auc:0.996032	train-auc:1
# [16]	eval-auc:0.99504	train-auc:1
# [17]	eval-auc:0.994544	train-auc:1
# [18]	eval-auc:0.995536	train-auc:1
# [19]	eval-auc:0.996528	train-auc:1
# [20]	eval-auc:0.996528	train-auc:1
# [21]	eval-auc:0.996528	train-auc:1
# [22]	eval-auc:0.995536	train-auc:1
# [23]	eval-auc:0.995536	train-auc:1
# [24]	eval-auc:0.995536	train-auc:1
# [25]	eval-auc:0.995536	train-auc:1
# [26]	eval-auc:0.995536	train-auc:1
# [27]	eval-auc:0.995536	train-auc:1
# [28]	eval-auc:0.995536	train-auc:1
# [29]	eval-auc:0.995536	train-auc:1
# True Positives(spam) = 26
# True Negatives(ham)  = 69
# False Positives(actual=ham, predicted=spam) = 3
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 94.06%
# Recall = 92.86%
# Specificity = 95.83%
# train = 2600, test = 100
# [0]	eval-auc:0.988928	train-auc:0.998089
# [1]	eval-auc:0.997669	train-auc:0.99989
# [2]	eval-auc:1	train-auc:0.999996
# [3]	eval-auc:0.999417	train-auc:1
# [4]	eval-auc:0.999417	train-auc:1
# [5]	eval-auc:0.999417	train-auc:1
# [6]	eval-auc:0.999417	train-auc:1
# [7]	eval-auc:1	train-auc:1
# [8]	eval-auc:0.999417	train-auc:1
# [9]	eval-auc:0.999417	train-auc:1
# [10]	eval-auc:0.999417	train-auc:1
# [11]	eval-auc:0.999417	train-auc:1
# [12]	eval-auc:0.999417	train-auc:1
# [13]	eval-auc:0.999417	train-auc:1
# [14]	eval-auc:0.999417	train-auc:1
# [15]	eval-auc:0.999417	train-auc:1
# [16]	eval-auc:0.999417	train-auc:1
# [17]	eval-auc:0.999417	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:0.999417	train-auc:1
# [20]	eval-auc:0.999417	train-auc:1
# [21]	eval-auc:0.999417	train-auc:1
# [22]	eval-auc:0.999417	train-auc:1
# [23]	eval-auc:0.999417	train-auc:1
# [24]	eval-auc:0.999417	train-auc:1
# [25]	eval-auc:0.999417	train-auc:1
# [26]	eval-auc:0.999417	train-auc:1
# [27]	eval-auc:0.999417	train-auc:1
# [28]	eval-auc:0.999417	train-auc:1
# [29]	eval-auc:0.999417	train-auc:1
# True Positives(spam) = 21
# True Negatives(ham)  = 78
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 98.02%
# Recall = 95.45%
# Specificity = 100.00%
# train = 2700, test = 100
# [0]	eval-auc:0.965696	train-auc:0.998014
# [1]	eval-auc:0.990904	train-auc:0.999599
# [2]	eval-auc:0.992204	train-auc:0.999946
# [3]	eval-auc:0.992723	train-auc:0.999994
# [4]	eval-auc:0.992723	train-auc:1
# [5]	eval-auc:0.992723	train-auc:1
# [6]	eval-auc:0.991684	train-auc:1
# [7]	eval-auc:0.992204	train-auc:1
# [8]	eval-auc:0.992204	train-auc:1
# [9]	eval-auc:0.990645	train-auc:1
# [10]	eval-auc:0.989605	train-auc:1
# [11]	eval-auc:0.988566	train-auc:1
# [12]	eval-auc:0.990125	train-auc:1
# [13]	eval-auc:0.990125	train-auc:1
# [14]	eval-auc:0.991164	train-auc:1
# [15]	eval-auc:0.992204	train-auc:1
# [16]	eval-auc:0.992723	train-auc:1
# [17]	eval-auc:0.992723	train-auc:1
# [18]	eval-auc:0.992204	train-auc:1
# [19]	eval-auc:0.993243	train-auc:1
# [20]	eval-auc:0.992204	train-auc:1
# [21]	eval-auc:0.991684	train-auc:1
# [22]	eval-auc:0.991684	train-auc:1
# [23]	eval-auc:0.991164	train-auc:1
# [24]	eval-auc:0.991164	train-auc:1
# [25]	eval-auc:0.991164	train-auc:1
# [26]	eval-auc:0.991164	train-auc:1
# [27]	eval-auc:0.991164	train-auc:1
# [28]	eval-auc:0.991164	train-auc:1
# [29]	eval-auc:0.991164	train-auc:1
# True Positives(spam) = 25
# True Negatives(ham)  = 70
# False Positives(actual=ham, predicted=spam) = 4
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 94.06%
# Recall = 96.15%
# Specificity = 94.59%
# train = 2800, test = 100
# [0]	eval-auc:0.971203	train-auc:0.998092
# [1]	eval-auc:0.979672	train-auc:0.999888
# [2]	eval-auc:0.985884	train-auc:0.999984
# [3]	eval-auc:0.985319	train-auc:1
# [4]	eval-auc:0.987578	train-auc:1
# [5]	eval-auc:0.989836	train-auc:1
# [6]	eval-auc:0.99153	train-auc:1
# [7]	eval-auc:0.99266	train-auc:1
# [8]	eval-auc:0.993224	train-auc:1
# [9]	eval-auc:0.993224	train-auc:1
# [10]	eval-auc:0.990966	train-auc:1
# [11]	eval-auc:0.993224	train-auc:1
# [12]	eval-auc:0.99266	train-auc:1
# [13]	eval-auc:0.99266	train-auc:1
# [14]	eval-auc:0.993224	train-auc:1
# [15]	eval-auc:0.993224	train-auc:1
# [16]	eval-auc:0.994918	train-auc:1
# [17]	eval-auc:0.995483	train-auc:1
# [18]	eval-auc:0.995483	train-auc:1
# [19]	eval-auc:0.995483	train-auc:1
# [20]	eval-auc:0.995483	train-auc:1
# [21]	eval-auc:0.995483	train-auc:1
# [22]	eval-auc:0.995483	train-auc:1
# [23]	eval-auc:0.993789	train-auc:1
# [24]	eval-auc:0.994918	train-auc:1
# [25]	eval-auc:0.995483	train-auc:1
# [26]	eval-auc:0.995483	train-auc:1
# [27]	eval-auc:0.994918	train-auc:1
# [28]	eval-auc:0.996047	train-auc:1
# [29]	eval-auc:0.996047	train-auc:1
# True Positives(spam) = 22
# True Negatives(ham)  = 76
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 97.03%
# Recall = 95.65%
# Specificity = 98.70%
# train = 2900, test = 100
# [0]	eval-auc:0.983879	train-auc:0.99831
# [1]	eval-auc:0.997272	train-auc:0.999866
# [2]	eval-auc:0.999504	train-auc:0.999987
# [3]	eval-auc:0.999008	train-auc:1
# [4]	eval-auc:1	train-auc:1
# [5]	eval-auc:1	train-auc:1
# [6]	eval-auc:0.999504	train-auc:1
# [7]	eval-auc:1	train-auc:1
# [8]	eval-auc:1	train-auc:1
# [9]	eval-auc:1	train-auc:1
# [10]	eval-auc:1	train-auc:1
# [11]	eval-auc:1	train-auc:1
# [12]	eval-auc:1	train-auc:1
# [13]	eval-auc:1	train-auc:1
# [14]	eval-auc:1	train-auc:1
# [15]	eval-auc:1	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:1	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:1	train-auc:1
# [22]	eval-auc:1	train-auc:1
# [23]	eval-auc:1	train-auc:1
# [24]	eval-auc:1	train-auc:1
# [25]	eval-auc:1	train-auc:1
# [26]	eval-auc:1	train-auc:1
# [27]	eval-auc:1	train-auc:1
# [28]	eval-auc:1	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 28
# True Negatives(ham)  = 71
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 98.02%
# Recall = 100.00%
# Specificity = 98.61%
# train = 3000, test = 100
# [0]	eval-auc:0.974933	train-auc:0.998125
# [1]	eval-auc:0.9936	train-auc:0.999808
# [2]	eval-auc:0.9952	train-auc:0.99999
# [3]	eval-auc:0.995733	train-auc:1
# [4]	eval-auc:0.997333	train-auc:0.999999
# [5]	eval-auc:0.996267	train-auc:1
# [6]	eval-auc:0.996267	train-auc:1
# [7]	eval-auc:0.994667	train-auc:1
# [8]	eval-auc:0.994667	train-auc:1
# [9]	eval-auc:0.994667	train-auc:1
# [10]	eval-auc:0.994667	train-auc:1
# [11]	eval-auc:0.994667	train-auc:1
# [12]	eval-auc:0.995733	train-auc:1
# [13]	eval-auc:0.995733	train-auc:1
# [14]	eval-auc:0.9952	train-auc:1
# [15]	eval-auc:0.9952	train-auc:1
# [16]	eval-auc:0.995733	train-auc:1
# [17]	eval-auc:0.995733	train-auc:1
# [18]	eval-auc:0.995733	train-auc:1
# [19]	eval-auc:0.995733	train-auc:1
# [20]	eval-auc:0.996267	train-auc:1
# [21]	eval-auc:0.996267	train-auc:1
# [22]	eval-auc:0.995733	train-auc:1
# [23]	eval-auc:0.995733	train-auc:1
# [24]	eval-auc:0.995733	train-auc:1
# [25]	eval-auc:0.995733	train-auc:1
# [26]	eval-auc:0.995733	train-auc:1
# [27]	eval-auc:0.996267	train-auc:1
# [28]	eval-auc:0.995733	train-auc:1
# [29]	eval-auc:0.9952	train-auc:1
# True Positives(spam) = 24
# True Negatives(ham)  = 73
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 96.04%
# Recall = 96.00%
# Specificity = 97.33%
# train = 3100, test = 100
# [0]	eval-auc:0.975139	train-auc:0.997769
# [1]	eval-auc:0.989345	train-auc:0.999828
# [2]	eval-auc:0.989345	train-auc:0.999971
# [3]	eval-auc:0.993404	train-auc:1
# [4]	eval-auc:0.99239	train-auc:1
# [5]	eval-auc:0.994419	train-auc:1
# [6]	eval-auc:0.994926	train-auc:1
# [7]	eval-auc:0.994419	train-auc:1
# [8]	eval-auc:0.994926	train-auc:1
# [9]	eval-auc:0.995434	train-auc:1
# [10]	eval-auc:0.995941	train-auc:1
# [11]	eval-auc:0.995434	train-auc:1
# [12]	eval-auc:0.994926	train-auc:1
# [13]	eval-auc:0.995434	train-auc:1
# [14]	eval-auc:0.995434	train-auc:1
# [15]	eval-auc:0.995434	train-auc:1
# [16]	eval-auc:0.994926	train-auc:1
# [17]	eval-auc:0.994926	train-auc:1
# [18]	eval-auc:0.995434	train-auc:1
# [19]	eval-auc:0.995434	train-auc:1
# [20]	eval-auc:0.995941	train-auc:1
# [21]	eval-auc:0.994926	train-auc:1
# [22]	eval-auc:0.995434	train-auc:1
# [23]	eval-auc:0.995434	train-auc:1
# [24]	eval-auc:0.995434	train-auc:1
# [25]	eval-auc:0.995434	train-auc:1
# [26]	eval-auc:0.995434	train-auc:1
# [27]	eval-auc:0.995434	train-auc:1
# [28]	eval-auc:0.994926	train-auc:1
# [29]	eval-auc:0.994926	train-auc:1
# True Positives(spam) = 26
# True Negatives(ham)  = 71
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 96.04%
# Recall = 96.30%
# Specificity = 97.26%
# train = 3200, test = 100
# [0]	eval-auc:0.979955	train-auc:0.998235
# [1]	eval-auc:0.995483	train-auc:0.99989
# [2]	eval-auc:0.996612	train-auc:0.999988
# [3]	eval-auc:0.997741	train-auc:1
# [4]	eval-auc:0.997741	train-auc:1
# [5]	eval-auc:0.998871	train-auc:1
# [6]	eval-auc:0.998871	train-auc:1
# [7]	eval-auc:0.998871	train-auc:1
# [8]	eval-auc:0.998871	train-auc:1
# [9]	eval-auc:0.998871	train-auc:1
# [10]	eval-auc:0.998306	train-auc:1
# [11]	eval-auc:0.998306	train-auc:1
# [12]	eval-auc:0.998871	train-auc:1
# [13]	eval-auc:0.998306	train-auc:1
# [14]	eval-auc:0.998871	train-auc:1
# [15]	eval-auc:0.998871	train-auc:1
# [16]	eval-auc:0.998871	train-auc:1
# [17]	eval-auc:0.998306	train-auc:1
# [18]	eval-auc:0.998871	train-auc:1
# [19]	eval-auc:0.998871	train-auc:1
# [20]	eval-auc:0.998871	train-auc:1
# [21]	eval-auc:0.998871	train-auc:1
# [22]	eval-auc:0.998871	train-auc:1
# [23]	eval-auc:0.998871	train-auc:1
# [24]	eval-auc:0.999435	train-auc:1
# [25]	eval-auc:0.999435	train-auc:1
# [26]	eval-auc:0.999435	train-auc:1
# [27]	eval-auc:0.999435	train-auc:1
# [28]	eval-auc:0.999435	train-auc:1
# [29]	eval-auc:0.999435	train-auc:1
# True Positives(spam) = 22
# True Negatives(ham)  = 77
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 98.02%
# Recall = 95.65%
# Specificity = 100.00%
# train = 3300, test = 100
# [0]	eval-auc:0.9696	train-auc:0.998261
# [1]	eval-auc:0.989067	train-auc:0.999638
# [2]	eval-auc:0.9952	train-auc:0.999949
# [3]	eval-auc:0.996267	train-auc:0.999993
# [4]	eval-auc:0.9968	train-auc:1
# [5]	eval-auc:0.997333	train-auc:1
# [6]	eval-auc:0.9968	train-auc:1
# [7]	eval-auc:0.997333	train-auc:1
# [8]	eval-auc:0.9984	train-auc:1
# [9]	eval-auc:0.9984	train-auc:1
# [10]	eval-auc:0.9984	train-auc:1
# [11]	eval-auc:0.998933	train-auc:1
# [12]	eval-auc:0.9984	train-auc:1
# [13]	eval-auc:0.999467	train-auc:1
# [14]	eval-auc:0.998933	train-auc:1
# [15]	eval-auc:1	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:1	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:1	train-auc:1
# [22]	eval-auc:1	train-auc:1
# [23]	eval-auc:1	train-auc:1
# [24]	eval-auc:1	train-auc:1
# [25]	eval-auc:1	train-auc:1
# [26]	eval-auc:1	train-auc:1
# [27]	eval-auc:1	train-auc:1
# [28]	eval-auc:1	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 25
# True Negatives(ham)  = 73
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 97.03%
# Recall = 100.00%
# Specificity = 97.33%
# train = 3400, test = 100
# [0]	eval-auc:0.997661	train-auc:0.998335
# [1]	eval-auc:0.994802	train-auc:0.999855
# [2]	eval-auc:0.99948	train-auc:0.99999
# [3]	eval-auc:1	train-auc:0.999998
# [4]	eval-auc:1	train-auc:1
# [5]	eval-auc:1	train-auc:1
# [6]	eval-auc:1	train-auc:1
# [7]	eval-auc:1	train-auc:1
# [8]	eval-auc:1	train-auc:1
# [9]	eval-auc:1	train-auc:1
# [10]	eval-auc:1	train-auc:1
# [11]	eval-auc:1	train-auc:1
# [12]	eval-auc:1	train-auc:1
# [13]	eval-auc:1	train-auc:1
# [14]	eval-auc:1	train-auc:1
# [15]	eval-auc:1	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:1	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:1	train-auc:1
# [22]	eval-auc:1	train-auc:1
# [23]	eval-auc:1	train-auc:1
# [24]	eval-auc:1	train-auc:1
# [25]	eval-auc:1	train-auc:1
# [26]	eval-auc:1	train-auc:1
# [27]	eval-auc:1	train-auc:1
# [28]	eval-auc:1	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 25
# True Negatives(ham)  = 74
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 98.02%
# Recall = 96.15%
# Specificity = 100.00%
# train = 3500, test = 100
# [0]	eval-auc:0.9608	train-auc:0.998086
# [1]	eval-auc:0.953673	train-auc:0.999905
# [2]	eval-auc:0.989583	train-auc:0.999995
# [3]	eval-auc:0.989583	train-auc:0.999999
# [4]	eval-auc:0.989035	train-auc:1
# [5]	eval-auc:0.993969	train-auc:1
# [6]	eval-auc:0.993969	train-auc:1
# [7]	eval-auc:0.995066	train-auc:1
# [8]	eval-auc:0.993969	train-auc:1
# [9]	eval-auc:0.993969	train-auc:1
# [10]	eval-auc:0.993421	train-auc:1
# [11]	eval-auc:0.995614	train-auc:1
# [12]	eval-auc:0.994518	train-auc:1
# [13]	eval-auc:0.992325	train-auc:1
# [14]	eval-auc:0.993421	train-auc:1
# [15]	eval-auc:0.993421	train-auc:1
# [16]	eval-auc:0.993421	train-auc:1
# [17]	eval-auc:0.995066	train-auc:1
# [18]	eval-auc:0.993421	train-auc:1
# [19]	eval-auc:0.993969	train-auc:1
# [20]	eval-auc:0.994518	train-auc:1
# [21]	eval-auc:0.995066	train-auc:1
# [22]	eval-auc:0.995614	train-auc:1
# [23]	eval-auc:0.995066	train-auc:1
# [24]	eval-auc:0.992873	train-auc:1
# [25]	eval-auc:0.993421	train-auc:1
# [26]	eval-auc:0.993969	train-auc:1
# [27]	eval-auc:0.994518	train-auc:1
# [28]	eval-auc:0.993969	train-auc:1
# [29]	eval-auc:0.993421	train-auc:1
# True Positives(spam) = 21
# True Negatives(ham)  = 76
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 3
# Accuracy = 96.04%
# Recall = 87.50%
# Specificity = 100.00%
# train = 3600, test = 100
# [0]	eval-auc:0.976	train-auc:0.998096
# [1]	eval-auc:0.993867	train-auc:0.999892
# [2]	eval-auc:0.9968	train-auc:0.999995
# [3]	eval-auc:0.997333	train-auc:1
# [4]	eval-auc:0.999467	train-auc:1
# [5]	eval-auc:0.998933	train-auc:1
# [6]	eval-auc:0.998933	train-auc:1
# [7]	eval-auc:0.9984	train-auc:1
# [8]	eval-auc:0.998933	train-auc:1
# [9]	eval-auc:0.999467	train-auc:1
# [10]	eval-auc:0.998933	train-auc:1
# [11]	eval-auc:0.999467	train-auc:1
# [12]	eval-auc:0.999467	train-auc:1
# [13]	eval-auc:0.998933	train-auc:1
# [14]	eval-auc:0.999467	train-auc:1
# [15]	eval-auc:0.999467	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:0.998933	train-auc:1
# [18]	eval-auc:0.998933	train-auc:1
# [19]	eval-auc:0.998933	train-auc:1
# [20]	eval-auc:0.998933	train-auc:1
# [21]	eval-auc:0.998933	train-auc:1
# [22]	eval-auc:0.998933	train-auc:1
# [23]	eval-auc:0.998933	train-auc:1
# [24]	eval-auc:0.998933	train-auc:1
# [25]	eval-auc:0.998933	train-auc:1
# [26]	eval-auc:0.998933	train-auc:1
# [27]	eval-auc:0.998933	train-auc:1
# [28]	eval-auc:0.999467	train-auc:1
# [29]	eval-auc:0.999467	train-auc:1
# True Positives(spam) = 25
# True Negatives(ham)  = 74
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 98.02%
# Recall = 100.00%
# Specificity = 98.67%
# train = 3700, test = 100
# [0]	eval-auc:0.968555	train-auc:0.998075
# [1]	eval-auc:0.980509	train-auc:0.999933
# [2]	eval-auc:0.991164	train-auc:0.999997
# [3]	eval-auc:0.992723	train-auc:1
# [4]	eval-auc:0.996881	train-auc:1
# [5]	eval-auc:0.995842	train-auc:1
# [6]	eval-auc:0.993763	train-auc:1
# [7]	eval-auc:0.995322	train-auc:1
# [8]	eval-auc:0.994283	train-auc:1
# [9]	eval-auc:0.995842	train-auc:1
# [10]	eval-auc:0.994802	train-auc:1
# [11]	eval-auc:0.994802	train-auc:1
# [12]	eval-auc:0.994802	train-auc:1
# [13]	eval-auc:0.994802	train-auc:1
# [14]	eval-auc:0.994802	train-auc:1
# [15]	eval-auc:0.994802	train-auc:1
# [16]	eval-auc:0.995322	train-auc:1
# [17]	eval-auc:0.995842	train-auc:1
# [18]	eval-auc:0.994802	train-auc:1
# [19]	eval-auc:0.994802	train-auc:1
# [20]	eval-auc:0.995322	train-auc:1
# [21]	eval-auc:0.994802	train-auc:1
# [22]	eval-auc:0.995322	train-auc:1
# [23]	eval-auc:0.994802	train-auc:1
# [24]	eval-auc:0.995322	train-auc:1
# [25]	eval-auc:0.996362	train-auc:1
# [26]	eval-auc:0.996362	train-auc:1
# [27]	eval-auc:0.996881	train-auc:1
# [28]	eval-auc:0.996881	train-auc:1
# [29]	eval-auc:0.996881	train-auc:1
# True Positives(spam) = 24
# True Negatives(ham)  = 73
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 96.04%
# Recall = 92.31%
# Specificity = 98.65%
# train = 3800, test = 100
# [0]	eval-auc:0.965333	train-auc:0.997943
# [1]	eval-auc:0.9904	train-auc:0.999879
# [2]	eval-auc:0.9904	train-auc:0.999984
# [3]	eval-auc:0.9952	train-auc:0.999999
# [4]	eval-auc:0.997333	train-auc:1
# [5]	eval-auc:0.993067	train-auc:1
# [6]	eval-auc:0.9968	train-auc:1
# [7]	eval-auc:0.9968	train-auc:1
# [8]	eval-auc:0.997333	train-auc:1
# [9]	eval-auc:0.996267	train-auc:1
# [10]	eval-auc:0.994133	train-auc:1
# [11]	eval-auc:0.994667	train-auc:1
# [12]	eval-auc:0.995733	train-auc:1
# [13]	eval-auc:0.995733	train-auc:1
# [14]	eval-auc:0.995733	train-auc:1
# [15]	eval-auc:0.995733	train-auc:1
# [16]	eval-auc:0.9968	train-auc:1
# ...
# [18]	eval-auc:0.992204	train-auc:1
# [19]	eval-auc:0.991684	train-auc:1
# [20]	eval-auc:0.992723	train-auc:1
# [21]	eval-auc:0.992723	train-auc:1
# [22]	eval-auc:0.992723	train-auc:1
# [23]	eval-auc:0.992723	train-auc:1
# [24]	eval-auc:0.992723	train-auc:1
# [25]	eval-auc:0.992723	train-auc:1
# [26]	eval-auc:0.992723	train-auc:1
# [27]	eval-auc:0.993243	train-auc:1
# [28]	eval-auc:0.992723	train-auc:1
# [29]	eval-auc:0.992204	train-auc:1
# True Positives(spam) = 73
# True Negatives(ham)  = 24
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 96.04%
# Recall = 98.65%
# Specificity = 92.31%
# train = 4700, test = 100
# [0]	eval-auc:0.944901	train-auc:0.998194
# [1]	eval-auc:0.980811	train-auc:0.999764
# [2]	eval-auc:0.986842	train-auc:0.999973
# [3]	eval-auc:0.992873	train-auc:0.999999
# [4]	eval-auc:0.995066	train-auc:0.999999
# [5]	eval-auc:0.995614	train-auc:1
# [6]	eval-auc:0.994518	train-auc:1
# [7]	eval-auc:0.993421	train-auc:1
# [8]	eval-auc:0.995614	train-auc:1
# [9]	eval-auc:0.996711	train-auc:1
# [10]	eval-auc:0.996711	train-auc:1
# [11]	eval-auc:0.996711	train-auc:1
# [12]	eval-auc:0.995066	train-auc:1
# [13]	eval-auc:0.995614	train-auc:1
# [14]	eval-auc:0.996711	train-auc:1
# [15]	eval-auc:0.996711	train-auc:1
# [16]	eval-auc:0.996711	train-auc:1
# [17]	eval-auc:0.996162	train-auc:1
# [18]	eval-auc:0.996711	train-auc:1
# [19]	eval-auc:0.996711	train-auc:1
# [20]	eval-auc:0.996711	train-auc:1
# [21]	eval-auc:0.996711	train-auc:1
# [22]	eval-auc:0.997259	train-auc:1
# [23]	eval-auc:0.997259	train-auc:1
# [24]	eval-auc:0.997259	train-auc:1
# [25]	eval-auc:0.997259	train-auc:1
# [26]	eval-auc:0.997259	train-auc:1
# [27]	eval-auc:0.997259	train-auc:1
# [28]	eval-auc:0.996711	train-auc:1
# [29]	eval-auc:0.996711	train-auc:1
# True Positives(spam) = 73
# True Negatives(ham)  = 22
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 3
# Accuracy = 94.06%
# Recall = 96.05%
# Specificity = 91.67%
# train = 4800, test = 100
# [0]	eval-auc:0.997288	train-auc:0.998276
# [1]	eval-auc:0.998794	train-auc:0.999886
# [2]	eval-auc:0.996986	train-auc:0.999986
# [3]	eval-auc:0.996383	train-auc:1
# [4]	eval-auc:0.998192	train-auc:1
# [5]	eval-auc:0.998794	train-auc:1
# [6]	eval-auc:0.998794	train-auc:1
# [7]	eval-auc:0.997589	train-auc:1
# [8]	eval-auc:0.998192	train-auc:1
# [9]	eval-auc:0.997589	train-auc:1
# [10]	eval-auc:0.997589	train-auc:1
# [11]	eval-auc:0.998192	train-auc:1
# [12]	eval-auc:0.998794	train-auc:1
# [13]	eval-auc:0.998794	train-auc:1
# [14]	eval-auc:0.998794	train-auc:1
# [15]	eval-auc:0.998794	train-auc:1
# [16]	eval-auc:0.998794	train-auc:1
# [17]	eval-auc:0.998192	train-auc:1
# [18]	eval-auc:0.998192	train-auc:1
# [19]	eval-auc:0.998192	train-auc:1
# [20]	eval-auc:0.997589	train-auc:1
# [21]	eval-auc:0.998192	train-auc:1
# [22]	eval-auc:0.997589	train-auc:1
# [23]	eval-auc:0.998192	train-auc:1
# [24]	eval-auc:0.998192	train-auc:1
# [25]	eval-auc:0.997589	train-auc:1
# [26]	eval-auc:0.998192	train-auc:1
# [27]	eval-auc:0.998794	train-auc:1
# [28]	eval-auc:0.998794	train-auc:1
# [29]	eval-auc:0.998794	train-auc:1
# True Positives(spam) = 77
# True Negatives(ham)  = 20
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 96.04%
# Recall = 97.47%
# Specificity = 95.24%
# train = 4900, test = 100
# [0]	eval-auc:0.971081	train-auc:0.998442
# [1]	eval-auc:0.99036	train-auc:0.999816
# [2]	eval-auc:0.993912	train-auc:0.999977
# [3]	eval-auc:0.996449	train-auc:0.999994
# [4]	eval-auc:0.998985	train-auc:0.999999
# [5]	eval-auc:1	train-auc:1
# [6]	eval-auc:1	train-auc:1
# [7]	eval-auc:0.999493	train-auc:1
# [8]	eval-auc:1	train-auc:1
# [9]	eval-auc:0.999493	train-auc:1
# [10]	eval-auc:1	train-auc:1
# [11]	eval-auc:1	train-auc:1
# [12]	eval-auc:1	train-auc:1
# [13]	eval-auc:1	train-auc:1
# [14]	eval-auc:1	train-auc:1
# [15]	eval-auc:1	train-auc:1
# [16]	eval-auc:1	train-auc:1
# [17]	eval-auc:1	train-auc:1
# [18]	eval-auc:1	train-auc:1
# [19]	eval-auc:1	train-auc:1
# [20]	eval-auc:1	train-auc:1
# [21]	eval-auc:1	train-auc:1
# [22]	eval-auc:1	train-auc:1
# [23]	eval-auc:1	train-auc:1
# [24]	eval-auc:1	train-auc:1
# [25]	eval-auc:1	train-auc:1
# [26]	eval-auc:1	train-auc:1
# [27]	eval-auc:1	train-auc:1
# [28]	eval-auc:1	train-auc:1
# [29]	eval-auc:1	train-auc:1
# True Positives(spam) = 73
# True Negatives(ham)  = 27
# False Positives(actual=ham, predicted=spam) = 0
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 99.01%
# Recall = 100.00%
# Specificity = 100.00%
# train = 5000, test = 100
# [0]	eval-auc:0.965753	train-auc:0.99836
# [1]	eval-auc:0.991375	train-auc:0.999822
# [2]	eval-auc:0.992897	train-auc:0.999985
# [3]	eval-auc:0.995941	train-auc:0.999999
# [4]	eval-auc:0.995941	train-auc:1
# [5]	eval-auc:0.997463	train-auc:1
# [6]	eval-auc:0.997971	train-auc:1
# [7]	eval-auc:0.998985	train-auc:1
# [8]	eval-auc:0.998985	train-auc:1
# [9]	eval-auc:0.998985	train-auc:1
# [10]	eval-auc:0.998985	train-auc:1
# [11]	eval-auc:0.998478	train-auc:1
# [12]	eval-auc:0.998985	train-auc:1
# [13]	eval-auc:0.998985	train-auc:1
# [14]	eval-auc:0.998985	train-auc:1
# [15]	eval-auc:0.998985	train-auc:1
# [16]	eval-auc:0.998985	train-auc:1
# [17]	eval-auc:0.998985	train-auc:1
# [18]	eval-auc:0.998985	train-auc:1
# [19]	eval-auc:0.998985	train-auc:1
# [20]	eval-auc:0.998985	train-auc:1
# [21]	eval-auc:0.998985	train-auc:1
# [22]	eval-auc:0.998985	train-auc:1
# [23]	eval-auc:0.998985	train-auc:1
# [24]	eval-auc:0.998985	train-auc:1
# [25]	eval-auc:0.998985	train-auc:1
# [26]	eval-auc:0.998985	train-auc:1
# [27]	eval-auc:0.998985	train-auc:1
# [28]	eval-auc:0.998985	train-auc:1
# [29]	eval-auc:0.998985	train-auc:1
# True Positives(spam) = 72
# True Negatives(ham)  = 26
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 97.03%
# Recall = 98.63%
# Specificity = 96.30%
# train = 5100, test = 100
# [0]	eval-auc:0.8968	train-auc:0.998338
# [1]	eval-auc:0.936533	train-auc:0.9998
# [2]	eval-auc:0.9856	train-auc:0.999976
# [3]	eval-auc:0.985067	train-auc:0.999996
# [4]	eval-auc:0.984	train-auc:0.999999
# [5]	eval-auc:0.981867	train-auc:1
# [6]	eval-auc:0.9888	train-auc:1
# [7]	eval-auc:0.988267	train-auc:1
# [8]	eval-auc:0.993067	train-auc:1
# [9]	eval-auc:0.993067	train-auc:1
# [10]	eval-auc:0.995733	train-auc:1
# [11]	eval-auc:0.9952	train-auc:1
# [12]	eval-auc:0.994667	train-auc:1
# [13]	eval-auc:0.994133	train-auc:1
# [14]	eval-auc:0.9936	train-auc:1
# [15]	eval-auc:0.993067	train-auc:1
# [16]	eval-auc:0.993067	train-auc:1
# [17]	eval-auc:0.992533	train-auc:1
# [18]	eval-auc:0.9936	train-auc:1
# [19]	eval-auc:0.993067	train-auc:1
# [20]	eval-auc:0.992	train-auc:1
# [21]	eval-auc:0.992	train-auc:1
# [22]	eval-auc:0.991467	train-auc:1
# [23]	eval-auc:0.991467	train-auc:1
# [24]	eval-auc:0.993067	train-auc:1
# [25]	eval-auc:0.991467	train-auc:1
# [26]	eval-auc:0.9936	train-auc:1
# [27]	eval-auc:0.990933	train-auc:1
# [28]	eval-auc:0.993067	train-auc:1
# [29]	eval-auc:0.992533	train-auc:1
# True Positives(spam) = 74
# True Negatives(ham)  = 22
# False Positives(actual=ham, predicted=spam) = 3
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 95.05%
# Recall = 98.67%
# Specificity = 88.00%
# train = 5200, test = 100
# [0]	eval-auc:0.913867	train-auc:0.998247
# [1]	eval-auc:0.9504	train-auc:0.999781
# [2]	eval-auc:0.957067	train-auc:0.999984
# [3]	eval-auc:0.973067	train-auc:1
# [4]	eval-auc:0.970933	train-auc:1
# [5]	eval-auc:0.9784	train-auc:1
# [6]	eval-auc:0.9808	train-auc:1
# [7]	eval-auc:0.978667	train-auc:1
# [8]	eval-auc:0.976	train-auc:1
# [9]	eval-auc:0.981867	train-auc:1
# [10]	eval-auc:0.985067	train-auc:1
# [11]	eval-auc:0.9888	train-auc:1
# [12]	eval-auc:0.9888	train-auc:1
# [13]	eval-auc:0.9904	train-auc:1
# [14]	eval-auc:0.989867	train-auc:1
# [15]	eval-auc:0.989867	train-auc:1
# [16]	eval-auc:0.989333	train-auc:1
# [17]	eval-auc:0.9888	train-auc:1
# [18]	eval-auc:0.989333	train-auc:1
# [19]	eval-auc:0.9904	train-auc:1
# [20]	eval-auc:0.991467	train-auc:1
# [21]	eval-auc:0.991467	train-auc:1
# [22]	eval-auc:0.991467	train-auc:1
# [23]	eval-auc:0.990933	train-auc:1
# [24]	eval-auc:0.990933	train-auc:1
# [25]	eval-auc:0.992	train-auc:1
# [26]	eval-auc:0.992	train-auc:1
# [27]	eval-auc:0.992	train-auc:1
# [28]	eval-auc:0.990933	train-auc:1
# [29]	eval-auc:0.991467	train-auc:1
# True Positives(spam) = 73
# True Negatives(ham)  = 23
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 95.05%
# Recall = 97.33%
# Specificity = 92.00%
# train = 5300, test = 100
# [0]	eval-auc:0.993658	train-auc:0.998301
# [1]	eval-auc:0.994165	train-auc:0.999683
# [2]	eval-auc:0.997463	train-auc:0.999957
# [3]	eval-auc:0.997463	train-auc:0.999991
# [4]	eval-auc:0.997971	train-auc:0.999998
# [5]	eval-auc:0.997463	train-auc:1
# [6]	eval-auc:0.998478	train-auc:1
# [7]	eval-auc:0.998478	train-auc:1
# [8]	eval-auc:0.998985	train-auc:1
# [9]	eval-auc:0.998478	train-auc:1
# [10]	eval-auc:0.998478	train-auc:1
# [11]	eval-auc:0.998478	train-auc:1
# [12]	eval-auc:0.998478	train-auc:1
# [13]	eval-auc:0.998478	train-auc:1
# [14]	eval-auc:0.998478	train-auc:1
# [15]	eval-auc:0.998478	train-auc:1
# [16]	eval-auc:0.998478	train-auc:1
# [17]	eval-auc:0.998985	train-auc:1
# [18]	eval-auc:0.998985	train-auc:1
# [19]	eval-auc:0.999493	train-auc:1
# [20]	eval-auc:0.999493	train-auc:1
# [21]	eval-auc:0.999493	train-auc:1
# [22]	eval-auc:0.999493	train-auc:1
# [23]	eval-auc:0.999493	train-auc:1
# [24]	eval-auc:0.999493	train-auc:1
# [25]	eval-auc:0.999493	train-auc:1
# [26]	eval-auc:0.999493	train-auc:1
# [27]	eval-auc:0.999493	train-auc:1
# [28]	eval-auc:0.998985	train-auc:1
# [29]	eval-auc:0.998985	train-auc:1
# True Positives(spam) = 73
# True Negatives(ham)  = 24
# False Positives(actual=ham, predicted=spam) = 3
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 96.04%
# Recall = 100.00%
# Specificity = 88.89%
# train = 5400, test = 100
# [0]	eval-auc:0.921518	train-auc:0.998257
# [1]	eval-auc:0.983368	train-auc:0.999797
# [2]	eval-auc:0.991684	train-auc:0.999978
# [3]	eval-auc:0.994802	train-auc:0.999991
# [4]	eval-auc:0.997401	train-auc:1
# [5]	eval-auc:0.997921	train-auc:1
# [6]	eval-auc:0.998441	train-auc:1
# [7]	eval-auc:0.998441	train-auc:1
# [8]	eval-auc:0.998441	train-auc:1
# [9]	eval-auc:0.998441	train-auc:1
# [10]	eval-auc:0.99896	train-auc:1
# [11]	eval-auc:0.998441	train-auc:1
# [12]	eval-auc:0.998441	train-auc:1
# [13]	eval-auc:0.998441	train-auc:1
# [14]	eval-auc:0.99896	train-auc:1
# [15]	eval-auc:0.99896	train-auc:1
# [16]	eval-auc:0.99896	train-auc:1
# [17]	eval-auc:0.99896	train-auc:1
# [18]	eval-auc:0.99896	train-auc:1
# [19]	eval-auc:0.99896	train-auc:1
# [20]	eval-auc:0.998441	train-auc:1
# [21]	eval-auc:0.997921	train-auc:1
# [22]	eval-auc:0.998441	train-auc:1
# [23]	eval-auc:0.997401	train-auc:1
# [24]	eval-auc:0.997921	train-auc:1
# [25]	eval-auc:0.998441	train-auc:1
# [26]	eval-auc:0.998441	train-auc:1
# [27]	eval-auc:0.998441	train-auc:1
# [28]	eval-auc:0.997921	train-auc:1
# [29]	eval-auc:0.997921	train-auc:1
# True Positives(spam) = 74
# True Negatives(ham)  = 23
# False Positives(actual=ham, predicted=spam) = 3
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 96.04%
# Recall = 100.00%
# Specificity = 88.46%
# train = 5500, test = 100
# [0]	eval-auc:0.995434	train-auc:0.998423
# [1]	eval-auc:0.993404	train-auc:0.999784
# [2]	eval-auc:0.997717	train-auc:0.999972
# [3]	eval-auc:0.998224	train-auc:0.999995
# [4]	eval-auc:0.996702	train-auc:1
# [5]	eval-auc:0.996449	train-auc:1
# [6]	eval-auc:0.996449	train-auc:1
# [7]	eval-auc:0.995941	train-auc:1
# [8]	eval-auc:0.994926	train-auc:1
# [9]	eval-auc:0.994926	train-auc:1
# [10]	eval-auc:0.996956	train-auc:1
# [11]	eval-auc:0.995941	train-auc:1
# [12]	eval-auc:0.995941	train-auc:1
# [13]	eval-auc:0.995941	train-auc:1
# [14]	eval-auc:0.995941	train-auc:1
# [15]	eval-auc:0.996449	train-auc:1
# [16]	eval-auc:0.996449	train-auc:1
# [17]	eval-auc:0.996956	train-auc:1
# [18]	eval-auc:0.996956	train-auc:1
# [19]	eval-auc:0.996956	train-auc:1
# [20]	eval-auc:0.996956	train-auc:1
# [21]	eval-auc:0.996956	train-auc:1
# [22]	eval-auc:0.996956	train-auc:1
# [23]	eval-auc:0.996449	train-auc:1
# [24]	eval-auc:0.996449	train-auc:1
# [25]	eval-auc:0.996449	train-auc:1
# [26]	eval-auc:0.996956	train-auc:1
# [27]	eval-auc:0.996956	train-auc:1
# [28]	eval-auc:0.996956	train-auc:1
# [29]	eval-auc:0.996956	train-auc:1
# True Positives(spam) = 72
# True Negatives(ham)  = 26
# False Positives(actual=ham, predicted=spam) = 1
# False Negatives(actual=spam,predicted=ham) = 1
# Accuracy = 97.03%
# Recall = 98.63%
# Specificity = 96.30%
# train = 5600, test = 100
# [0]	eval-auc:0.939582	train-auc:0.998334
# [1]	eval-auc:0.93563	train-auc:0.999783
# [2]	eval-auc:0.952851	train-auc:0.999971
# [3]	eval-auc:0.978543	train-auc:0.999993
# [4]	eval-auc:0.98306	train-auc:0.999998
# [5]	eval-auc:0.985884	train-auc:1
# [6]	eval-auc:0.989272	train-auc:1
# [7]	eval-auc:0.993224	train-auc:1
# [8]	eval-auc:0.994353	train-auc:1
# [9]	eval-auc:0.99266	train-auc:1
# [10]	eval-auc:0.99153	train-auc:1
# [11]	eval-auc:0.990966	train-auc:1
# [12]	eval-auc:0.993224	train-auc:1
# [13]	eval-auc:0.995483	train-auc:1
# [14]	eval-auc:0.994353	train-auc:1
# [15]	eval-auc:0.994353	train-auc:1
# [16]	eval-auc:0.994353	train-auc:1
# [17]	eval-auc:0.993789	train-auc:1
# [18]	eval-auc:0.994353	train-auc:1
# [19]	eval-auc:0.994353	train-auc:1
# [20]	eval-auc:0.993789	train-auc:1
# [21]	eval-auc:0.994353	train-auc:1
# [22]	eval-auc:0.994353	train-auc:1
# [23]	eval-auc:0.995483	train-auc:1
# [24]	eval-auc:0.996047	train-auc:1
# [25]	eval-auc:0.995483	train-auc:1
# [26]	eval-auc:0.994918	train-auc:1
# [27]	eval-auc:0.994918	train-auc:1
# [28]	eval-auc:0.994918	train-auc:1
# [29]	eval-auc:0.995483	train-auc:1
# True Positives(spam) = 77
# True Negatives(ham)  = 21
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 97.03%
# Recall = 100.00%
# Specificity = 91.30%
# train = 5700, test = 100
# [0]	eval-auc:0.944901	train-auc:0.998298
# [1]	eval-auc:0.9375	train-auc:0.999827
# [2]	eval-auc:0.959156	train-auc:0.999984
# [3]	eval-auc:0.979441	train-auc:0.999992
# [4]	eval-auc:0.985197	train-auc:0.999999
# [5]	eval-auc:0.99068	train-auc:1
# [6]	eval-auc:0.991776	train-auc:1
# [7]	eval-auc:0.993969	train-auc:1
# [8]	eval-auc:0.992873	train-auc:1
# [9]	eval-auc:0.992873	train-auc:1
# [10]	eval-auc:0.993421	train-auc:1
# [11]	eval-auc:0.994518	train-auc:1
# [12]	eval-auc:0.993969	train-auc:1
# [13]	eval-auc:0.993421	train-auc:1
# [14]	eval-auc:0.993969	train-auc:1
# [15]	eval-auc:0.994518	train-auc:1
# [16]	eval-auc:0.995614	train-auc:1
# [17]	eval-auc:0.995614	train-auc:1
# [18]	eval-auc:0.996162	train-auc:1
# [19]	eval-auc:0.996711	train-auc:1
# [20]	eval-auc:0.996162	train-auc:1
# [21]	eval-auc:0.995614	train-auc:1
# [22]	eval-auc:0.995614	train-auc:1
# [23]	eval-auc:0.995614	train-auc:1
# [24]	eval-auc:0.996162	train-auc:1
# [25]	eval-auc:0.996162	train-auc:1
# [26]	eval-auc:0.996162	train-auc:1
# [27]	eval-auc:0.996711	train-auc:1
# [28]	eval-auc:0.996162	train-auc:1
# [29]	eval-auc:0.996162	train-auc:1
# True Positives(spam) = 76
# True Negatives(ham)  = 22
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 0
# Accuracy = 97.03%
# Recall = 100.00%
# Specificity = 91.67%
# train = 5800, test = 198
# [0]	eval-auc:0.955333	train-auc:0.998274
# [1]	eval-auc:0.961163	train-auc:0.999774
# [2]	eval-auc:0.984568	train-auc:0.99993
# [3]	eval-auc:0.991427	train-auc:0.999989
# [4]	eval-auc:0.993141	train-auc:0.999999
# [5]	eval-auc:0.996399	train-auc:1
# [6]	eval-auc:0.995027	train-auc:1
# [7]	eval-auc:0.997085	train-auc:1
# [8]	eval-auc:0.998628	train-auc:1
# [9]	eval-auc:0.998628	train-auc:1
# [10]	eval-auc:0.998628	train-auc:1
# [11]	eval-auc:0.9988	train-auc:1
# [12]	eval-auc:0.9988	train-auc:1
# [13]	eval-auc:0.998971	train-auc:1
# [14]	eval-auc:0.998457	train-auc:1
# [15]	eval-auc:0.998628	train-auc:1
# [16]	eval-auc:0.9988	train-auc:1
# [17]	eval-auc:0.9988	train-auc:1
# [18]	eval-auc:0.998628	train-auc:1
# [19]	eval-auc:0.998285	train-auc:1
# [20]	eval-auc:0.998457	train-auc:1
# [21]	eval-auc:0.9988	train-auc:1
# [22]	eval-auc:0.998628	train-auc:1
# [23]	eval-auc:0.998628	train-auc:1
# [24]	eval-auc:0.998628	train-auc:1
# [25]	eval-auc:0.998628	train-auc:1
# [26]	eval-auc:0.9988	train-auc:1
# [27]	eval-auc:0.998457	train-auc:1
# [28]	eval-auc:0.998457	train-auc:1
# [29]	eval-auc:0.998457	train-auc:1
# True Positives(spam) = 160
# True Negatives(ham)  = 34
# False Positives(actual=ham, predicted=spam) = 2
# False Negatives(actual=spam,predicted=ham) = 2
# Accuracy = 97.49%
# Recall = 98.77%
# Specificity = 94.44%
# Done !

# %%
# Run when all the 6 enron datasets have been made to run
# Average of all the batches for each enron dataset
for i in range(6):
    enron_dataset="enron"+str(i+1)
    measure_after_iteration = pd.read_csv("Res/processed_data/measure_after_iteration_"+enron_dataset+".csv",sep=",")
    print(enron_dataset,np.round(np.mean(measure_after_iteration["Recall"]),1),np.round(np.mean(measure_after_iteration["Specificity"]),1))
# Out:
# ('enron1', 88.1, 97.6)
# ('enron2', 89.8, 97.7)
# ('enron3', 91.9, 98.2)
# ('enron4', 98.5, 93.5)
# ('enron5', 98.9, 91.2)
# ('enron6', 98.8, 89.1)

# %%
print("Completed !")
# Out:
# Completed !
